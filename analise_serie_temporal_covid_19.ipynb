# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from datetime import date


warnings.filterwarnings('ignore')

# %%
df_total = pd.read_csv('/content/cases-brazil-states.csv')
df_total.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 1       9  2020-02-25  Brazil  TOTAL  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 3       9  2020-02-26  Brazil  TOTAL  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0      1         0        0              0.0         0.00218
# 1      1         0        0              0.0         0.00048
# 2      1         0        1              0.0         0.00218
# 3      1         0        1              0.0         0.00048
# 4      1         0        1              0.0         0.00218
#
#    obitos_por_casos  recuperados  suspeitos  testes  testes_por_100k
# 0               0.0          NaN        NaN     NaN              NaN
# 1               0.0          NaN        NaN     NaN              NaN
# 2               0.0          NaN        NaN     NaN              NaN
# 3               0.0          NaN        NaN     NaN              NaN
# 4               0.0          NaN        NaN     NaN              NaN

# %%
df = df_total[df_total['estado'] != 'TOTAL']
df['data'] = pd.to_datetime(df_total['data']).dt.date
df.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0      1         0        0              0.0         0.00218
# 2      1         0        1              0.0         0.00218
# 4      1         0        1              0.0         0.00218
# 6      2         0        1              0.0         0.00436
# 8      2         0        2              0.0         0.00436
#
#    obitos_por_casos  recuperados  suspeitos  testes  testes_por_100k
# 0               0.0          NaN        NaN     NaN              NaN
# 2               0.0          NaN        NaN     NaN              NaN
# 4               0.0          NaN        NaN     NaN              NaN
# 6               0.0          NaN        NaN     NaN              NaN
# 8               0.0          NaN        NaN     NaN              NaN

# %%
plt.figure(figsize=(20, 8))
fig = sns.lineplot(x='data', y='Obitos', hue='estado', data=df)
fig.set_title('Óbitos por estado em função do tmepo', loc='left', fontsize=24)
fig.set_xlabel('Data', fontsize=24)
fig.set_ylabel('Óbitos', fontsize=24)
plt.show()

# %%
df_sp = df[df['estado'] == 'SP']
df_sp.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0      1         0        0              0.0         0.00218
# 2      1         0        1              0.0         0.00218
# 4      1         0        1              0.0         0.00218
# 6      2         0        1              0.0         0.00436
# 8      2         0        2              0.0         0.00436
#
#    obitos_por_casos  recuperados  suspeitos  testes  testes_por_100k
# 0               0.0          NaN        NaN     NaN              NaN
# 2               0.0          NaN        NaN     NaN              NaN
# 4               0.0          NaN        NaN     NaN              NaN
# 6               0.0          NaN        NaN     NaN              NaN
# 8               0.0          NaN        NaN     NaN              NaN

# %% [markdown]
# # $log(N) = x \longleftrightarrow  N = 10^x \\
# ln(N) = x \longleftrightarrow  N = e^x$

# %%
plt.figure(figsize=(20, 8))
fig = sns.lineplot(x='data', y='Obitos', hue='estado', data=df)
fig.set_title('Óbitos em função do tmepo no estado de SP', loc='left', fontsize=24)
fig.set_xlabel('Data', fontsize=24)
fig.set_ylabel('Óbitos', fontsize=24)
fig.set_yscale('log')
plt.show()

# %%
plt.figure(figsize=(20,8))
fig = sns.barplot(x='data', y='Obitos', hue='estado', data=df)
fig.set_title('Óbitos por estado em função do tempo', loc='left', fontsize=24)
fig.set_xlabel('Data', fontsize=24)
fig.set_ylabel('Óbitos', fontsize=24)
plt.show()

# %%
df_sp.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0      1         0        0              0.0         0.00218
# 2      1         0        1              0.0         0.00218
# 4      1         0        1              0.0         0.00218
# 6      2         0        1              0.0         0.00436
# 8      2         0        2              0.0         0.00436
#
#    obitos_por_casos  recuperados  suspeitos  testes  testes_por_100k
# 0               0.0          NaN        NaN     NaN              NaN
# 2               0.0          NaN        NaN     NaN              NaN
# 4               0.0          NaN        NaN     NaN              NaN
# 6               0.0          NaN        NaN     NaN              NaN
# 8               0.0          NaN        NaN     NaN              NaN

# %%
plt.figure(figsize=(20, 8))
fig = plt.bar(df_sp.data, df_sp.suspeitos, label='Suspeitos')
plt.bar(df_sp.data, df_sp.recuperados, label='Recuperados')
plt.bar(df_sp.data, df_sp['Obitos'], label='Óbitos')
plt.xlabel('Data', fontsize=24)
plt.ylabel('Óbitos, recuperados e suspeitos no estado de SP', fontsize=24, rotation=90)
plt.legend()
plt.show()

# %%
def plotar_linha(titulo, xlabel, ylabel, x, y, dataset, hue=None):
  ax = sns.lineplot(x=x, y=y, hue=hue, data=dataset)
  ax.figure.set_size_inches(12, 6)
  ax.set_title(titulo, loc='left', fontsize=20)
  ax.set_xlabel(xlabel, fontsize=20)
  ax.set_ylabel(ylabel, fontsize=20, rotation=90)

# %%
def plotar_barra(titulo, xlabel, ylabel, x, y, dataset):
  plt.figure(figsize=(20, 6))
  ax = plt.bar(dataset[x], dataset[y])
  plt.title(titulo, loc='left', fontsize=20)
  plt.xlabel(xlabel, fontsize=20)
  plt.ylabel(ylabel, fontsize=20, rotation=90)

# %%
plotar_barra('Novos casos em SP', 'Data', 'Novos casos', 'data', 'novosCasos', df_sp)

# %%
df_sp['aceleracaoCasos'] = df_sp['novosCasos'].diff()
df_sp['aceleracaoObitos'] = df_sp['novosObitos'].diff()
df_sp.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  casosMS  obitos_por_100k  casos_por_100k  \
# 0      1         0        0              0.0         0.00218
# 2      1         0        1              0.0         0.00218
# 4      1         0        1              0.0         0.00218
# 6      2         0        1              0.0         0.00436
# 8      2         0        2              0.0         0.00436
#
#    obitos_por_casos  recuperados  suspeitos  testes  testes_por_100k  \
# 0               0.0          NaN        NaN     NaN              NaN
# 2               0.0          NaN        NaN     NaN              NaN
# 4               0.0          NaN        NaN     NaN              NaN
# 6               0.0          NaN        NaN     NaN              NaN
# 8               0.0          NaN        NaN     NaN              NaN
#
#    aceleracaoCasos  aceleracaoObitos
# 0              NaN               NaN
# 2             -1.0               0.0
# 4              0.0               0.0
# 6              1.0               0.0
# 8             -1.0               0.0

# %%
plotar_barra('Aceleração de Óbitos em SP', 'Data', 'Aceleração', 'data', 'aceleracaoObitos', df_sp)

# %%
df_sp['aceleracaoRecuperados'] = df_sp['recuperados'].diff()
df_sp.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  ...  obitos_por_100k  casos_por_100k  obitos_por_casos  \
# 0      1         0  ...              0.0         0.00218               0.0
# 2      1         0  ...              0.0         0.00218               0.0
# 4      1         0  ...              0.0         0.00218               0.0
# 6      2         0  ...              0.0         0.00436               0.0
# 8      2         0  ...              0.0         0.00436               0.0
#
#    recuperados  suspeitos  testes  testes_por_100k  aceleracaoCasos  \
# 0          NaN        NaN     NaN              NaN              NaN
# 2          NaN        NaN     NaN              NaN             -1.0
# 4          NaN        NaN     NaN              NaN              0.0
# 6          NaN        NaN     NaN              NaN              1.0
# 8          NaN        NaN     NaN              NaN             -1.0
#
#    aceleracaoObitos  aceleracaoRecuperados
# 0               NaN                    NaN
# 2               0.0                    NaN
# 4               0.0                    NaN
# 6               0.0                    NaN
# 8               0.0                    NaN
#
# [5 rows x 21 columns]

# %%
plotar_barra('Aceleração de recuperados em SP', 'Data', 'Aceleração', 'data', 'aceleracaoRecuperados', df_sp)

# %%
df_sp['mediaObitos'] = df_sp.novosObitos.rolling(window=7, center=False).mean()
df_sp['mediaObitos_14'] = df_sp.novosObitos.rolling(window=14, center=False).mean()
df_sp.head(14)
# Out:
#     semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0        9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2        9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4        9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6        9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8        9  2020-02-29  Brazil     SP  TOTAL            0       0           0
# 10      10  2020-03-01  Brazil     SP  TOTAL            0       0           0
# 12      10  2020-03-02  Brazil     SP  TOTAL            0       0           0
# 14      10  2020-03-03  Brazil     SP  TOTAL            0       0           0
# 16      10  2020-03-04  Brazil     SP  TOTAL            0       0           1
# 19      10  2020-03-05  Brazil     SP  TOTAL            0       0           3
# 24      10  2020-03-06  Brazil     SP  TOTAL            0       0           4
# 30      10  2020-03-07  Brazil     SP  TOTAL            0       0           3
# 38      11  2020-03-08  Brazil     SP  TOTAL            0       0           3
# 46      11  2020-03-09  Brazil     SP  TOTAL            0       0           0
#
#     Casos  obitosMS  ...  obitos_por_casos  recuperados  suspeitos  testes  \
# 0       1         0  ...               0.0          NaN        NaN     NaN
# 2       1         0  ...               0.0          NaN        NaN     NaN
# 4       1         0  ...               0.0          NaN        NaN     NaN
# 6       2         0  ...               0.0          NaN        NaN     NaN
# 8       2         0  ...               0.0          NaN        NaN     NaN
# 10      2         0  ...               0.0          NaN        NaN     NaN
# 12      2         0  ...               0.0          NaN        NaN     NaN
# 14      2         0  ...               0.0          NaN        NaN     NaN
# 16      3         0  ...               0.0          NaN        NaN     NaN
# 19      6         0  ...               0.0          NaN        NaN     NaN
# 24     10         0  ...               0.0          NaN        NaN     NaN
# 30     13         0  ...               0.0          NaN        NaN     NaN
# 38     16         0  ...               0.0          NaN        NaN     NaN
# 46     16         0  ...               0.0          NaN        NaN     NaN
#
#     testes_por_100k  aceleracaoCasos  aceleracaoObitos  aceleracaoRecuperados  \
# 0               NaN              NaN               NaN                    NaN
# 2               NaN             -1.0               0.0                    NaN
# 4               NaN              0.0               0.0                    NaN
# 6               NaN              1.0               0.0                    NaN
# 8               NaN             -1.0               0.0                    NaN
# 10              NaN              0.0               0.0                    NaN
# 12              NaN              0.0               0.0                    NaN
# 14              NaN              0.0               0.0                    NaN
# 16              NaN              1.0               0.0                    NaN
# 19              NaN              2.0               0.0                    NaN
# 24              NaN              1.0               0.0                    NaN
# 30              NaN             -1.0               0.0                    NaN
# 38              NaN              0.0               0.0                    NaN
# 46              NaN             -3.0               0.0                    NaN
#
#     mediaObitos  mediaObitos_14
# 0           NaN             NaN
# 2           NaN             NaN
# 4           NaN             NaN
# 6           NaN             NaN
# 8           NaN             NaN
# 10          NaN             NaN
# 12          0.0             NaN
# 14          0.0             NaN
# 16          0.0             NaN
# 19          0.0             NaN
# 24          0.0             NaN
# 30          0.0             NaN
# 38          0.0             NaN
# 46          0.0             0.0
#
# [14 rows x 23 columns]

# %%
plotar_linha('Média móvel de óbitos em SP', 'Data', 'Média', 'data', 'mediaObitos', df_sp)
plotar_linha('Média móvel de óbitos em SP em 14 dias', 'Data', 'Média', 'data', 'mediaObitos_14', df_sp)
plt.bar(df_sp['data'], df_sp['novosObitos'], color='lightgrey')
# Out:
# <BarContainer object of 158 artists>

# %%
from pandas.plotting import autocorrelation_plot

# %%
ax = plt.figure(figsize=(12, 6))
ax.suptitle('Correlação dos óbitos', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_sp['Obitos'])
ax.show()

# %%
ax = plt.figure(figsize=(12, 6))
ax.suptitle('Correlação de novos óbitos', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_sp['novosObitos'])
ax.show()

# %%
ax = plt.figure(figsize=(12, 6))
ax.suptitle('Correlação dos novos óbitos (média móvel)', fontsize=18, x=0.26, y=0.95)
# Pega a partir do sétimo porque a janela é de 7 em 7 dias, devido aos 6 primeiros dias não terem dados
# o gráfico não é exibido se colocar df_sp['mediaObitos'], outra correção pode ser usar df_sp['mediaObitos'].fillna(0)
# removendo os NaN (not a number), como provado na próxima célula
autocorrelation_plot(df_sp['mediaObitos'][7:])
ax.show()

# %%
ax = plt.figure(figsize=(12, 6))
ax.suptitle('Correlação dos novos óbitos (média móvel)', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_sp['mediaObitos'].fillna(0))
ax.show()

# %%
ax = plt.figure(figsize=(12, 6))
ax.suptitle('Autocorrelação da aceleração de óbitos', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_sp['aceleracaoObitos'][1:])
ax.show()

# %%
df_sp['mediaAccObitos'] = df_sp['aceleracaoObitos'][1:].rolling(window=7, center=False).mean()
ax = plt.figure(figsize=(12,6))
ax.suptitle('Autocorrelação da média da aceleração de óbitos', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_sp['mediaAccObitos'][7:])
ax.show()

# %%
df_sp['mes'] = pd.to_datetime(df_sp['data'])
df_sp['dia_da_semana'] = df_sp['mes'].dt.day_name()
df_sp.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  ...  testes  testes_por_100k  aceleracaoCasos  \
# 0      1         0  ...     NaN              NaN              NaN
# 2      1         0  ...     NaN              NaN             -1.0
# 4      1         0  ...     NaN              NaN              0.0
# 6      2         0  ...     NaN              NaN              1.0
# 8      2         0  ...     NaN              NaN             -1.0
#
#    aceleracaoObitos  aceleracaoRecuperados  mediaObitos  mediaObitos_14  \
# 0               NaN                    NaN          NaN             NaN
# 2               0.0                    NaN          NaN             NaN
# 4               0.0                    NaN          NaN             NaN
# 6               0.0                    NaN          NaN             NaN
# 8               0.0                    NaN          NaN             NaN
#
#    mediaAccObitos        mes  dia_da_semana
# 0             NaN 2020-02-25        Tuesday
# 2             NaN 2020-02-26      Wednesday
# 4             NaN 2020-02-27       Thursday
# 6             NaN 2020-02-28         Friday
# 8             NaN 2020-02-29       Saturday
#
# [5 rows x 26 columns]

# %%
dias_traduzidos = {
    'Sunday': 'Primeira',
    'Monday': 'Segunda',
    'Tuesday': 'Terça',
    'Wednesday': 'Quarta',
    'Thursday': 'Quinta',
    'Friday': 'Sexta',
    'Saturday': 'Sabado'
}

df_sp['dia_da_semana'] = df_sp['dia_da_semana'].map(dias_traduzidos)
df_sp.head()
# Out:
#    semana        data    pais estado cidade  novosObitos  Obitos  novosCasos  \
# 0       9  2020-02-25  Brazil     SP  TOTAL            0       0           1
# 2       9  2020-02-26  Brazil     SP  TOTAL            0       0           0
# 4       9  2020-02-27  Brazil     SP  TOTAL            0       0           0
# 6       9  2020-02-28  Brazil     SP  TOTAL            0       0           1
# 8       9  2020-02-29  Brazil     SP  TOTAL            0       0           0
#
#    Casos  obitosMS  ...  testes  testes_por_100k  aceleracaoCasos  \
# 0      1         0  ...     NaN              NaN              NaN
# 2      1         0  ...     NaN              NaN             -1.0
# 4      1         0  ...     NaN              NaN              0.0
# 6      2         0  ...     NaN              NaN              1.0
# 8      2         0  ...     NaN              NaN             -1.0
#
#    aceleracaoObitos  aceleracaoRecuperados  mediaObitos  mediaObitos_14  \
# 0               NaN                    NaN          NaN             NaN
# 2               0.0                    NaN          NaN             NaN
# 4               0.0                    NaN          NaN             NaN
# 6               0.0                    NaN          NaN             NaN
# 8               0.0                    NaN          NaN             NaN
#
#    mediaAccObitos        mes  dia_da_semana
# 0             NaN 2020-02-25          Terça
# 2             NaN 2020-02-26         Quarta
# 4             NaN 2020-02-27         Quinta
# 6             NaN 2020-02-28          Sexta
# 8             NaN 2020-02-29         Sabado
#
# [5 rows x 26 columns]

# %%
agrupados_sp = df_sp.groupby('dia_da_semana')['Obitos', 'novosObitos', 'aceleracaoObitos'].mean().round()
agrupados_sp['dia_da_semana'] = agrupados_sp.index
agrupados_sp.head(7)
# Out:
#                Obitos  novosObitos  aceleracaoObitos dia_da_semana
# dia_da_semana
# Primeira       6846.0         60.0             -95.0      Primeira
# Quarta         6975.0        181.0             -25.0        Quarta
# Quinta         7165.0        190.0               9.0        Quinta
# Sabado         6786.0        155.0             -17.0        Sabado
# Segunda        6887.0         41.0             -20.0       Segunda
# Sexta          7342.0        177.0             -13.0         Sexta
# Terça          6794.0        206.0             175.0         Terça

# %%
agrupados_sp = agrupados_sp.reindex(['Primeira', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sabado'])

# %%
ax = sns.barplot(agrupados_sp['dia_da_semana'], agrupados_sp.novosObitos)

# %%
def criar_features(df, label=None):
  df = df.copy()
  df['diasemana'] = df['mes'].dt.weekday
  df['diames'] = df['mes'].dt.day
  df['mes'] = df['mes'].dt.month

  X = df[['diasemana', 'mes', 'diames']]

  if label:
    y = df[label]
    return X, y
  return X

# %%
X, y = criar_features(df_sp, label='Obitos')
df_final = pd.concat([X, y], axis=1)
df_final.head(10)
# Out:
#     diasemana  mes  diames  Obitos
# 0           1    2      25       0
# 2           2    2      26       0
# 4           3    2      27       0
# 6           4    2      28       0
# 8           5    2      29       0
# 10          6    3       1       0
# 12          0    3       2       0
# 14          1    3       3       0
# 16          2    3       4       0
# 19          3    3       5       0

# %%
graphic = sns.pairplot(df_final.dropna(),
                       hue='mes',
                       x_vars=['diasemana', 'diames', 'mes'],
                       y_vars='Obitos')
graphic.fig.set_size_inches(12, 6)
graphic.axes[0, 0].set_xlabel('Dia da semana', fontsize=15)
graphic.axes[0, 1].set_xlabel('Dia do mês', fontsize=15)
graphic.axes[0, 2].set_xlabel('Mês', fontsize=15)
graphic.axes[0, 0].set_ylabel('Óbitos', fontsize=15)

plt.suptitle('Óbitos por dia da semana, do mês e por mês', fontsize=15)
plt.show()
