# %% [markdown]
# # [Word2Vec: treinamento de Word Embedding](https://cursos.alura.com.br/course/word2vec-treinamento-word-embedding)
#
# ## Datasets
#
# * [Site NILC USP com Word Embeddings](http://nilc.icmc.usp.br/nilc/index.php/repositorio-de-word-embeddings-do-nilc)
#
# * [Arquivo treino](https://caelum-online-public.s3.amazonaws.com/1638-word-embedding/treino.csv)
#
# * [Arquivo teste](https://caelum-online-public.s3.amazonaws.com/1638-word-embedding/teste.csv)

# %%
# Abaixo as versões utilizadas no google colab
# !pip list -v
# Out:
# Package                       Version               Location                                Installer
# ----------------------------- --------------------- --------------------------------------- ---------
# absl-py                       1.4.0                 /usr/local/lib/python3.10/dist-packages pip
# alabaster                     0.7.13                /usr/local/lib/python3.10/dist-packages pip
# albumentations                1.2.1                 /usr/local/lib/python3.10/dist-packages pip
# altair                        4.2.2                 /usr/local/lib/python3.10/dist-packages pip
# anyio                         3.6.2                 /usr/local/lib/python3.10/dist-packages pip
# appdirs                       1.4.4                 /usr/local/lib/python3.10/dist-packages pip
# argon2-cffi                   21.3.0                /usr/local/lib/python3.10/dist-packages pip
# argon2-cffi-bindings          21.2.0                /usr/local/lib/python3.10/dist-packages pip
# array-record                  0.2.0                 /usr/local/lib/python3.10/dist-packages pip
# arviz                         0.15.1                /usr/local/lib/python3.10/dist-packages pip
# astropy                       5.2.2                 /usr/local/lib/python3.10/dist-packages pip
# astunparse                    1.6.3                 /usr/local/lib/python3.10/dist-packages pip
# attrs                         23.1.0                /usr/local/lib/python3.10/dist-packages pip
# audioread                     3.0.0                 /usr/local/lib/python3.10/dist-packages pip
# autograd                      1.5                   /usr/local/lib/python3.10/dist-packages pip
# Babel                         2.12.1                /usr/local/lib/python3.10/dist-packages pip
# backcall                      0.2.0                 /usr/local/lib/python3.10/dist-packages pip
# beautifulsoup4                4.11.2                /usr/local/lib/python3.10/dist-packages pip
# bleach                        6.0.0                 /usr/local/lib/python3.10/dist-packages pip
# blis                          0.7.9                 /usr/local/lib/python3.10/dist-packages pip
# blosc2                        2.0.0                 /usr/local/lib/python3.10/dist-packages pip
# bokeh                         2.4.3                 /usr/local/lib/python3.10/dist-packages pip
# branca                        0.6.0                 /usr/local/lib/python3.10/dist-packages pip
# build                         0.10.0                /usr/local/lib/python3.10/dist-packages pip
# CacheControl                  0.12.11               /usr/local/lib/python3.10/dist-packages pip
# cached-property               1.5.2                 /usr/local/lib/python3.10/dist-packages pip
# cachetools                    5.3.0                 /usr/local/lib/python3.10/dist-packages pip
# catalogue                     2.0.8                 /usr/local/lib/python3.10/dist-packages pip
# certifi                       2022.12.7             /usr/local/lib/python3.10/dist-packages pip
# cffi                          1.15.1                /usr/local/lib/python3.10/dist-packages pip
# chardet                       4.0.0                 /usr/local/lib/python3.10/dist-packages pip
# charset-normalizer            2.0.12                /usr/local/lib/python3.10/dist-packages pip
# chex                          0.1.7                 /usr/local/lib/python3.10/dist-packages pip
# click                         8.1.3                 /usr/local/lib/python3.10/dist-packages pip
# cloudpickle                   2.2.1                 /usr/local/lib/python3.10/dist-packages pip
# cmake                         3.25.2                /usr/local/lib/python3.10/dist-packages pip
# cmdstanpy                     1.1.0                 /usr/local/lib/python3.10/dist-packages pip
# colorcet                      3.0.1                 /usr/local/lib/python3.10/dist-packages pip
# colorlover                    0.3.0                 /usr/local/lib/python3.10/dist-packages pip
# community                     1.0.0b1               /usr/local/lib/python3.10/dist-packages pip
# confection                    0.0.4                 /usr/local/lib/python3.10/dist-packages pip
# cons                          0.4.5                 /usr/local/lib/python3.10/dist-packages pip
# contextlib2                   0.6.0.post1           /usr/local/lib/python3.10/dist-packages pip
# contourpy                     1.0.7                 /usr/local/lib/python3.10/dist-packages pip
# convertdate                   2.4.0                 /usr/local/lib/python3.10/dist-packages pip
# cryptography                  40.0.2                /usr/local/lib/python3.10/dist-packages pip
# cufflinks                     0.17.3                /usr/local/lib/python3.10/dist-packages pip
# cvxopt                        1.3.0                 /usr/local/lib/python3.10/dist-packages pip
# cvxpy                         1.3.1                 /usr/local/lib/python3.10/dist-packages pip
# cycler                        0.11.0                /usr/local/lib/python3.10/dist-packages pip
# cymem                         2.0.7                 /usr/local/lib/python3.10/dist-packages pip
# Cython                        0.29.34               /usr/local/lib/python3.10/dist-packages pip
# dask                          2022.12.1             /usr/local/lib/python3.10/dist-packages pip
# datascience                   0.17.6                /usr/local/lib/python3.10/dist-packages pip
# db-dtypes                     1.1.1                 /usr/local/lib/python3.10/dist-packages pip
# dbus-python                   1.2.16                /usr/lib/python3/dist-packages
# debugpy                       1.6.6                 /usr/local/lib/python3.10/dist-packages pip
# decorator                     4.4.2                 /usr/local/lib/python3.10/dist-packages pip
# defusedxml                    0.7.1                 /usr/local/lib/python3.10/dist-packages pip
# distributed                   2022.12.1             /usr/local/lib/python3.10/dist-packages pip
# dlib                          19.24.1               /usr/local/lib/python3.10/dist-packages pip
# dm-tree                       0.1.8                 /usr/local/lib/python3.10/dist-packages pip
# docutils                      0.16                  /usr/local/lib/python3.10/dist-packages pip
# dopamine-rl                   4.0.6                 /usr/local/lib/python3.10/dist-packages pip
# duckdb                        0.7.1                 /usr/local/lib/python3.10/dist-packages pip
# earthengine-api               0.1.350               /usr/local/lib/python3.10/dist-packages pip
# easydict                      1.10                  /usr/local/lib/python3.10/dist-packages pip
# ecos                          2.0.12                /usr/local/lib/python3.10/dist-packages pip
# editdistance                  0.6.2                 /usr/local/lib/python3.10/dist-packages pip
# en-core-web-sm                3.5.0                 /usr/local/lib/python3.10/dist-packages pip
# entrypoints                   0.4                   /usr/local/lib/python3.10/dist-packages pip
# ephem                         4.1.4                 /usr/local/lib/python3.10/dist-packages pip
# et-xmlfile                    1.1.0                 /usr/local/lib/python3.10/dist-packages pip
# etils                         1.2.0                 /usr/local/lib/python3.10/dist-packages pip
# etuples                       0.3.8                 /usr/local/lib/python3.10/dist-packages pip
# exceptiongroup                1.1.1                 /usr/local/lib/python3.10/dist-packages pip
# fastai                        2.7.12                /usr/local/lib/python3.10/dist-packages pip
# fastcore                      1.5.29                /usr/local/lib/python3.10/dist-packages pip
# fastdownload                  0.0.7                 /usr/local/lib/python3.10/dist-packages pip
# fastjsonschema                2.16.3                /usr/local/lib/python3.10/dist-packages pip
# fastprogress                  1.0.3                 /usr/local/lib/python3.10/dist-packages pip
# fastrlock                     0.8.1                 /usr/local/lib/python3.10/dist-packages pip
# filelock                      3.12.0                /usr/local/lib/python3.10/dist-packages pip
# firebase-admin                5.3.0                 /usr/local/lib/python3.10/dist-packages pip
# Flask                         2.2.4                 /usr/local/lib/python3.10/dist-packages pip
# flatbuffers                   23.3.3                /usr/local/lib/python3.10/dist-packages pip
# flax                          0.6.9                 /usr/local/lib/python3.10/dist-packages pip
# folium                        0.14.0                /usr/local/lib/python3.10/dist-packages pip
# fonttools                     4.39.3                /usr/local/lib/python3.10/dist-packages pip
# frozendict                    2.3.7                 /usr/local/lib/python3.10/dist-packages pip
# fsspec                        2023.4.0              /usr/local/lib/python3.10/dist-packages pip
# future                        0.18.3                /usr/local/lib/python3.10/dist-packages pip
# gast                          0.4.0                 /usr/local/lib/python3.10/dist-packages pip
# GDAL                          3.3.2                 /usr/local/lib/python3.10/dist-packages pip
# gdown                         4.6.6                 /usr/local/lib/python3.10/dist-packages pip
# gensim                        4.3.1                 /usr/local/lib/python3.10/dist-packages pip
# geographiclib                 2.0                   /usr/local/lib/python3.10/dist-packages pip
# geopy                         2.3.0                 /usr/local/lib/python3.10/dist-packages pip
# gin-config                    0.5.0                 /usr/local/lib/python3.10/dist-packages pip
# glob2                         0.7                   /usr/local/lib/python3.10/dist-packages pip
# google                        2.0.3                 /usr/local/lib/python3.10/dist-packages pip
# google-api-core               2.11.0                /usr/local/lib/python3.10/dist-packages pip
# google-api-python-client      2.84.0                /usr/local/lib/python3.10/dist-packages pip
# google-auth                   2.17.3                /usr/local/lib/python3.10/dist-packages pip
# google-auth-httplib2          0.1.0                 /usr/local/lib/python3.10/dist-packages pip
# google-auth-oauthlib          1.0.0                 /usr/local/lib/python3.10/dist-packages pip
# google-cloud-bigquery         3.9.0                 /usr/local/lib/python3.10/dist-packages pip
# google-cloud-bigquery-storage 2.19.1                /usr/local/lib/python3.10/dist-packages pip
# google-cloud-core             2.3.2                 /usr/local/lib/python3.10/dist-packages pip
# google-cloud-datastore        2.15.1                /usr/local/lib/python3.10/dist-packages pip
# google-cloud-firestore        2.11.0                /usr/local/lib/python3.10/dist-packages pip
# google-cloud-language         2.9.1                 /usr/local/lib/python3.10/dist-packages pip
# google-cloud-storage          2.8.0                 /usr/local/lib/python3.10/dist-packages pip
# google-cloud-translate        3.11.1                /usr/local/lib/python3.10/dist-packages pip
# google-colab                  1.0.0                 /usr/local/lib/python3.10/dist-packages pip
# google-crc32c                 1.5.0                 /usr/local/lib/python3.10/dist-packages pip
# google-pasta                  0.2.0                 /usr/local/lib/python3.10/dist-packages pip
# google-resumable-media        2.5.0                 /usr/local/lib/python3.10/dist-packages pip
# googleapis-common-protos      1.59.0                /usr/local/lib/python3.10/dist-packages pip
# googledrivedownloader         0.4                   /usr/local/lib/python3.10/dist-packages pip
# graphviz                      0.20.1                /usr/local/lib/python3.10/dist-packages pip
# greenlet                      2.0.2                 /usr/local/lib/python3.10/dist-packages pip
# grpcio                        1.54.0                /usr/local/lib/python3.10/dist-packages pip
# grpcio-status                 1.48.2                /usr/local/lib/python3.10/dist-packages pip
# gspread                       3.4.2                 /usr/local/lib/python3.10/dist-packages pip
# gspread-dataframe             3.0.8                 /usr/local/lib/python3.10/dist-packages pip
# gym                           0.25.2                /usr/local/lib/python3.10/dist-packages pip
# gym-notices                   0.0.8                 /usr/local/lib/python3.10/dist-packages pip
# h5netcdf                      1.1.0                 /usr/local/lib/python3.10/dist-packages pip
# h5py                          3.8.0                 /usr/local/lib/python3.10/dist-packages pip
# holidays                      0.25                  /usr/local/lib/python3.10/dist-packages pip
# holoviews                     1.15.4                /usr/local/lib/python3.10/dist-packages pip
# html5lib                      1.1                   /usr/local/lib/python3.10/dist-packages pip
# httpimport                    1.3.0                 /usr/local/lib/python3.10/dist-packages pip
# httplib2                      0.21.0                /usr/local/lib/python3.10/dist-packages pip
# humanize                      4.6.0                 /usr/local/lib/python3.10/dist-packages pip
# hyperopt                      0.2.7                 /usr/local/lib/python3.10/dist-packages pip
# idna                          3.4                   /usr/local/lib/python3.10/dist-packages pip
# imageio                       2.25.1                /usr/local/lib/python3.10/dist-packages pip
# imageio-ffmpeg                0.4.8                 /usr/local/lib/python3.10/dist-packages pip
# imagesize                     1.4.1                 /usr/local/lib/python3.10/dist-packages pip
# imbalanced-learn              0.10.1                /usr/local/lib/python3.10/dist-packages pip
# imgaug                        0.4.0                 /usr/local/lib/python3.10/dist-packages pip
# importlib-resources           5.12.0                /usr/local/lib/python3.10/dist-packages pip
# imutils                       0.5.4                 /usr/local/lib/python3.10/dist-packages pip
# inflect                       6.0.4                 /usr/local/lib/python3.10/dist-packages pip
# iniconfig                     2.0.0                 /usr/local/lib/python3.10/dist-packages pip
# intel-openmp                  2023.1.0              /usr/local/lib/python3.10/dist-packages pip
# ipykernel                     5.5.6                 /usr/local/lib/python3.10/dist-packages pip
# ipython                       7.34.0                /usr/local/lib/python3.10/dist-packages pip
# ipython-genutils              0.2.0                 /usr/local/lib/python3.10/dist-packages pip
# ipython-sql                   0.4.1                 /usr/local/lib/python3.10/dist-packages pip
# ipywidgets                    7.7.1                 /usr/local/lib/python3.10/dist-packages pip
# itsdangerous                  2.1.2                 /usr/local/lib/python3.10/dist-packages pip
# jax                           0.4.10                /usr/local/lib/python3.10/dist-packages pip
# jaxlib                        0.4.10+cuda11.cudnn86 /usr/local/lib/python3.10/dist-packages pip
# jieba                         0.42.1                /usr/local/lib/python3.10/dist-packages pip
# Jinja2                        3.1.2                 /usr/local/lib/python3.10/dist-packages pip
# joblib                        1.2.0                 /usr/local/lib/python3.10/dist-packages pip
# jsonpickle                    3.0.1                 /usr/local/lib/python3.10/dist-packages pip
# jsonschema                    4.3.3                 /usr/local/lib/python3.10/dist-packages pip
# jupyter-client                6.1.12                /usr/local/lib/python3.10/dist-packages pip
# jupyter-console               6.1.0                 /usr/local/lib/python3.10/dist-packages pip
# jupyter_core                  5.3.0                 /usr/local/lib/python3.10/dist-packages pip
# jupyter-server                1.24.0                /usr/local/lib/python3.10/dist-packages pip
# jupyterlab-pygments           0.2.2                 /usr/local/lib/python3.10/dist-packages pip
# jupyterlab-widgets            3.0.7                 /usr/local/lib/python3.10/dist-packages pip
# kaggle                        1.5.13                /usr/local/lib/python3.10/dist-packages pip
# keras                         2.12.0                /usr/local/lib/python3.10/dist-packages pip
# kiwisolver                    1.4.4                 /usr/local/lib/python3.10/dist-packages pip
# korean-lunar-calendar         0.3.1                 /usr/local/lib/python3.10/dist-packages pip
# langcodes                     3.3.0                 /usr/local/lib/python3.10/dist-packages pip
# lazy_loader                   0.2                   /usr/local/lib/python3.10/dist-packages pip
# libclang                      16.0.0                /usr/local/lib/python3.10/dist-packages pip
# librosa                       0.10.0.post2          /usr/local/lib/python3.10/dist-packages pip
# lightgbm                      3.3.5                 /usr/local/lib/python3.10/dist-packages pip
# lit                           16.0.5                /usr/local/lib/python3.10/dist-packages pip
# llvmlite                      0.39.1                /usr/local/lib/python3.10/dist-packages pip
# locket                        1.0.0                 /usr/local/lib/python3.10/dist-packages pip
# logical-unification           0.4.5                 /usr/local/lib/python3.10/dist-packages pip
# LunarCalendar                 0.0.9                 /usr/local/lib/python3.10/dist-packages pip
# lxml                          4.9.2                 /usr/local/lib/python3.10/dist-packages pip
# Markdown                      3.4.3                 /usr/local/lib/python3.10/dist-packages pip
# markdown-it-py                2.2.0                 /usr/local/lib/python3.10/dist-packages pip
# MarkupSafe                    2.1.2                 /usr/local/lib/python3.10/dist-packages pip
# matplotlib                    3.7.1                 /usr/local/lib/python3.10/dist-packages pip
# matplotlib-inline             0.1.6                 /usr/local/lib/python3.10/dist-packages pip
# matplotlib-venn               0.11.9                /usr/local/lib/python3.10/dist-packages pip
# mdurl                         0.1.2                 /usr/local/lib/python3.10/dist-packages pip
# miniKanren                    1.0.3                 /usr/local/lib/python3.10/dist-packages pip
# missingno                     0.5.2                 /usr/local/lib/python3.10/dist-packages pip
# mistune                       0.8.4                 /usr/local/lib/python3.10/dist-packages pip
# mizani                        0.8.1                 /usr/local/lib/python3.10/dist-packages pip
# mkl                           2019.0                /usr/local/lib/python3.10/dist-packages pip
# ml-dtypes                     0.1.0                 /usr/local/lib/python3.10/dist-packages pip
# mlxtend                       0.14.0                /usr/local/lib/python3.10/dist-packages pip
# more-itertools                9.1.0                 /usr/local/lib/python3.10/dist-packages pip
# moviepy                       1.0.3                 /usr/local/lib/python3.10/dist-packages pip
# mpmath                        1.3.0                 /usr/local/lib/python3.10/dist-packages pip
# msgpack                       1.0.5                 /usr/local/lib/python3.10/dist-packages pip
# multipledispatch              0.6.0                 /usr/local/lib/python3.10/dist-packages pip
# multitasking                  0.0.11                /usr/local/lib/python3.10/dist-packages pip
# murmurhash                    1.0.9                 /usr/local/lib/python3.10/dist-packages pip
# music21                       8.1.0                 /usr/local/lib/python3.10/dist-packages pip
# natsort                       8.3.1                 /usr/local/lib/python3.10/dist-packages pip
# nbclient                      0.7.4                 /usr/local/lib/python3.10/dist-packages pip
# nbconvert                     6.5.4                 /usr/local/lib/python3.10/dist-packages pip
# nbformat                      5.8.0                 /usr/local/lib/python3.10/dist-packages pip
# nest-asyncio                  1.5.6                 /usr/local/lib/python3.10/dist-packages pip
# networkx                      3.1                   /usr/local/lib/python3.10/dist-packages pip
# nibabel                       3.0.2                 /usr/local/lib/python3.10/dist-packages pip
# nltk                          3.8.1                 /usr/local/lib/python3.10/dist-packages pip
# notebook                      6.4.8                 /usr/local/lib/python3.10/dist-packages pip
# numba                         0.56.4                /usr/local/lib/python3.10/dist-packages pip
# numexpr                       2.8.4                 /usr/local/lib/python3.10/dist-packages pip
# numpy                         1.22.4                /usr/local/lib/python3.10/dist-packages pip
# oauth2client                  4.1.3                 /usr/local/lib/python3.10/dist-packages pip
# oauthlib                      3.2.2                 /usr/local/lib/python3.10/dist-packages pip
# opencv-contrib-python         4.7.0.72              /usr/local/lib/python3.10/dist-packages pip
# opencv-python                 4.7.0.72              /usr/local/lib/python3.10/dist-packages pip
# opencv-python-headless        4.7.0.72              /usr/local/lib/python3.10/dist-packages pip
# openpyxl                      3.0.10                /usr/local/lib/python3.10/dist-packages pip
# opt-einsum                    3.3.0                 /usr/local/lib/python3.10/dist-packages pip
# optax                         0.1.5                 /usr/local/lib/python3.10/dist-packages pip
# orbax-checkpoint              0.2.1                 /usr/local/lib/python3.10/dist-packages pip
# osqp                          0.6.2.post8           /usr/local/lib/python3.10/dist-packages pip
# packaging                     23.1                  /usr/local/lib/python3.10/dist-packages pip
# palettable                    3.3.3                 /usr/local/lib/python3.10/dist-packages pip
# pandas                        1.5.3                 /usr/local/lib/python3.10/dist-packages pip
# pandas-datareader             0.10.0                /usr/local/lib/python3.10/dist-packages pip
# pandas-gbq                    0.17.9                /usr/local/lib/python3.10/dist-packages pip
# pandocfilters                 1.5.0                 /usr/local/lib/python3.10/dist-packages pip
# panel                         0.14.4                /usr/local/lib/python3.10/dist-packages pip
# param                         1.13.0                /usr/local/lib/python3.10/dist-packages pip
# parso                         0.8.3                 /usr/local/lib/python3.10/dist-packages pip
# partd                         1.4.0                 /usr/local/lib/python3.10/dist-packages pip
# pathlib                       1.0.1                 /usr/local/lib/python3.10/dist-packages pip
# pathy                         0.10.1                /usr/local/lib/python3.10/dist-packages pip
# patsy                         0.5.3                 /usr/local/lib/python3.10/dist-packages pip
# pexpect                       4.8.0                 /usr/local/lib/python3.10/dist-packages pip
# pickleshare                   0.7.5                 /usr/local/lib/python3.10/dist-packages pip
# Pillow                        8.4.0                 /usr/local/lib/python3.10/dist-packages pip
# pip                           23.1.2                /usr/local/lib/python3.10/dist-packages pip
# pip-tools                     6.13.0                /usr/local/lib/python3.10/dist-packages pip
# platformdirs                  3.3.0                 /usr/local/lib/python3.10/dist-packages pip
# plotly                        5.13.1                /usr/local/lib/python3.10/dist-packages pip
# plotnine                      0.10.1                /usr/local/lib/python3.10/dist-packages pip
# pluggy                        1.0.0                 /usr/local/lib/python3.10/dist-packages pip
# polars                        0.17.3                /usr/local/lib/python3.10/dist-packages pip
# pooch                         1.6.0                 /usr/local/lib/python3.10/dist-packages pip
# portpicker                    1.3.9                 /usr/local/lib/python3.10/dist-packages pip
# prefetch-generator            1.0.3                 /usr/local/lib/python3.10/dist-packages pip
# preshed                       3.0.8                 /usr/local/lib/python3.10/dist-packages pip
# prettytable                   0.7.2                 /usr/local/lib/python3.10/dist-packages pip
# proglog                       0.1.10                /usr/local/lib/python3.10/dist-packages pip
# progressbar2                  4.2.0                 /usr/local/lib/python3.10/dist-packages pip
# prometheus-client             0.16.0                /usr/local/lib/python3.10/dist-packages pip
# promise                       2.3                   /usr/local/lib/python3.10/dist-packages pip
# prompt-toolkit                3.0.38                /usr/local/lib/python3.10/dist-packages pip
# prophet                       1.1.3                 /usr/local/lib/python3.10/dist-packages pip
# proto-plus                    1.22.2                /usr/local/lib/python3.10/dist-packages pip
# protobuf                      3.20.3                /usr/local/lib/python3.10/dist-packages pip
# psutil                        5.9.5                 /usr/local/lib/python3.10/dist-packages pip
# psycopg2                      2.9.6                 /usr/local/lib/python3.10/dist-packages pip
# ptyprocess                    0.7.0                 /usr/local/lib/python3.10/dist-packages pip
# py-cpuinfo                    9.0.0                 /usr/local/lib/python3.10/dist-packages pip
# py4j                          0.10.9.7              /usr/local/lib/python3.10/dist-packages pip
# pyarrow                       9.0.0                 /usr/local/lib/python3.10/dist-packages pip
# pyasn1                        0.5.0                 /usr/local/lib/python3.10/dist-packages pip
# pyasn1-modules                0.3.0                 /usr/local/lib/python3.10/dist-packages pip
# pycocotools                   2.0.6                 /usr/local/lib/python3.10/dist-packages pip
# pycparser                     2.21                  /usr/local/lib/python3.10/dist-packages pip
# pyct                          0.5.0                 /usr/local/lib/python3.10/dist-packages pip
# pydantic                      1.10.7                /usr/local/lib/python3.10/dist-packages pip
# pydata-google-auth            1.7.0                 /usr/local/lib/python3.10/dist-packages pip
# pydot                         1.4.2                 /usr/local/lib/python3.10/dist-packages pip
# pydot-ng                      2.0.0                 /usr/local/lib/python3.10/dist-packages pip
# pydotplus                     2.0.2                 /usr/local/lib/python3.10/dist-packages pip
# PyDrive                       1.3.1                 /usr/local/lib/python3.10/dist-packages pip
# pyerfa                        2.0.0.3               /usr/local/lib/python3.10/dist-packages pip
# pygame                        2.3.0                 /usr/local/lib/python3.10/dist-packages pip
# Pygments                      2.14.0                /usr/local/lib/python3.10/dist-packages pip
# PyGObject                     3.36.0                /usr/lib/python3/dist-packages
# pymc                          5.1.2                 /usr/local/lib/python3.10/dist-packages pip
# PyMeeus                       0.5.12                /usr/local/lib/python3.10/dist-packages pip
# pymystem3                     0.2.0                 /usr/local/lib/python3.10/dist-packages pip
# PyOpenGL                      3.1.6                 /usr/local/lib/python3.10/dist-packages pip
# pyparsing                     3.0.9                 /usr/local/lib/python3.10/dist-packages pip
# pyproject_hooks               1.0.0                 /usr/local/lib/python3.10/dist-packages pip
# pyrsistent                    0.19.3                /usr/local/lib/python3.10/dist-packages pip
# PySocks                       1.7.1                 /usr/local/lib/python3.10/dist-packages pip
# pytensor                      2.10.1                /usr/local/lib/python3.10/dist-packages pip
# pytest                        7.2.2                 /usr/local/lib/python3.10/dist-packages pip
# python-apt                    0.0.0                 /usr/local/lib/python3.10/dist-packages
# python-dateutil               2.8.2                 /usr/local/lib/python3.10/dist-packages pip
# python-louvain                0.16                  /usr/local/lib/python3.10/dist-packages pip
# python-slugify                8.0.1                 /usr/local/lib/python3.10/dist-packages pip
# python-utils                  3.5.2                 /usr/local/lib/python3.10/dist-packages pip
# pytz                          2022.7.1              /usr/local/lib/python3.10/dist-packages pip
# pytz-deprecation-shim         0.1.0.post0           /usr/local/lib/python3.10/dist-packages pip
# pyviz-comms                   2.2.1                 /usr/local/lib/python3.10/dist-packages pip
# PyWavelets                    1.4.1                 /usr/local/lib/python3.10/dist-packages pip
# PyYAML                        6.0                   /usr/local/lib/python3.10/dist-packages pip
# pyzmq                         23.2.1                /usr/local/lib/python3.10/dist-packages pip
# qdldl                         0.1.7                 /usr/local/lib/python3.10/dist-packages pip
# qudida                        0.0.4                 /usr/local/lib/python3.10/dist-packages pip
# regex                         2022.10.31            /usr/local/lib/python3.10/dist-packages pip
# requests                      2.27.1                /usr/local/lib/python3.10/dist-packages pip
# requests-oauthlib             1.3.1                 /usr/local/lib/python3.10/dist-packages pip
# requests-unixsocket           0.2.0                 /usr/lib/python3/dist-packages
# requirements-parser           0.5.0                 /usr/local/lib/python3.10/dist-packages pip
# rich                          13.3.4                /usr/local/lib/python3.10/dist-packages pip
# rpy2                          3.5.5                 /usr/local/lib/python3.10/dist-packages pip
# rsa                           4.9                   /usr/local/lib/python3.10/dist-packages pip
# scikit-image                  0.19.3                /usr/local/lib/python3.10/dist-packages pip
# scikit-learn                  1.2.2                 /usr/local/lib/python3.10/dist-packages pip
# scipy                         1.10.1                /usr/local/lib/python3.10/dist-packages pip
# scs                           3.2.3                 /usr/local/lib/python3.10/dist-packages pip
# seaborn                       0.12.2                /usr/local/lib/python3.10/dist-packages pip
# Send2Trash                    1.8.0                 /usr/local/lib/python3.10/dist-packages pip
# setuptools                    67.7.2                /usr/local/lib/python3.10/dist-packages pip
# shapely                       2.0.1                 /usr/local/lib/python3.10/dist-packages pip
# six                           1.16.0                /usr/local/lib/python3.10/dist-packages pip
# sklearn-pandas                2.2.0                 /usr/local/lib/python3.10/dist-packages pip
# smart-open                    6.3.0                 /usr/local/lib/python3.10/dist-packages pip
# sniffio                       1.3.0                 /usr/local/lib/python3.10/dist-packages pip
# snowballstemmer               2.2.0                 /usr/local/lib/python3.10/dist-packages pip
# sortedcontainers              2.4.0                 /usr/local/lib/python3.10/dist-packages pip
# soundfile                     0.12.1                /usr/local/lib/python3.10/dist-packages pip
# soupsieve                     2.4.1                 /usr/local/lib/python3.10/dist-packages pip
# soxr                          0.3.5                 /usr/local/lib/python3.10/dist-packages pip
# spacy                         3.5.2                 /usr/local/lib/python3.10/dist-packages pip
# spacy-legacy                  3.0.12                /usr/local/lib/python3.10/dist-packages pip
# spacy-loggers                 1.0.4                 /usr/local/lib/python3.10/dist-packages pip
# Sphinx                        3.5.4                 /usr/local/lib/python3.10/dist-packages pip
# sphinxcontrib-applehelp       1.0.4                 /usr/local/lib/python3.10/dist-packages pip
# sphinxcontrib-devhelp         1.0.2                 /usr/local/lib/python3.10/dist-packages pip
# sphinxcontrib-htmlhelp        2.0.1                 /usr/local/lib/python3.10/dist-packages pip
# sphinxcontrib-jsmath          1.0.1                 /usr/local/lib/python3.10/dist-packages pip
# sphinxcontrib-qthelp          1.0.3                 /usr/local/lib/python3.10/dist-packages pip
# sphinxcontrib-serializinghtml 1.1.5                 /usr/local/lib/python3.10/dist-packages pip
# SQLAlchemy                    2.0.10                /usr/local/lib/python3.10/dist-packages pip
# sqlparse                      0.4.4                 /usr/local/lib/python3.10/dist-packages pip
# srsly                         2.4.6                 /usr/local/lib/python3.10/dist-packages pip
# statsmodels                   0.13.5                /usr/local/lib/python3.10/dist-packages pip
# sympy                         1.11.1                /usr/local/lib/python3.10/dist-packages pip
# tables                        3.8.0                 /usr/local/lib/python3.10/dist-packages pip
# tabulate                      0.8.10                /usr/local/lib/python3.10/dist-packages pip
# tblib                         1.7.0                 /usr/local/lib/python3.10/dist-packages pip
# tenacity                      8.2.2                 /usr/local/lib/python3.10/dist-packages pip
# tensorboard                   2.12.2                /usr/local/lib/python3.10/dist-packages pip
# tensorboard-data-server       0.7.0                 /usr/local/lib/python3.10/dist-packages pip
# tensorboard-plugin-wit        1.8.1                 /usr/local/lib/python3.10/dist-packages pip
# tensorflow                    2.12.0                /usr/local/lib/python3.10/dist-packages pip
# tensorflow-datasets           4.9.2                 /usr/local/lib/python3.10/dist-packages pip
# tensorflow-estimator          2.12.0                /usr/local/lib/python3.10/dist-packages pip
# tensorflow-gcs-config         2.12.0                /usr/local/lib/python3.10/dist-packages pip
# tensorflow-hub                0.13.0                /usr/local/lib/python3.10/dist-packages pip
# tensorflow-io-gcs-filesystem  0.32.0                /usr/local/lib/python3.10/dist-packages pip
# tensorflow-metadata           1.13.1                /usr/local/lib/python3.10/dist-packages pip
# tensorflow-probability        0.20.1                /usr/local/lib/python3.10/dist-packages pip
# tensorstore                   0.1.36                /usr/local/lib/python3.10/dist-packages pip
# termcolor                     2.3.0                 /usr/local/lib/python3.10/dist-packages pip
# terminado                     0.17.1                /usr/local/lib/python3.10/dist-packages pip
# text-unidecode                1.3                   /usr/local/lib/python3.10/dist-packages pip
# textblob                      0.17.1                /usr/local/lib/python3.10/dist-packages pip
# tf-slim                       1.1.0                 /usr/local/lib/python3.10/dist-packages pip
# thinc                         8.1.9                 /usr/local/lib/python3.10/dist-packages pip
# threadpoolctl                 3.1.0                 /usr/local/lib/python3.10/dist-packages pip
# tifffile                      2023.4.12             /usr/local/lib/python3.10/dist-packages pip
# tinycss2                      1.2.1                 /usr/local/lib/python3.10/dist-packages pip
# toml                          0.10.2                /usr/local/lib/python3.10/dist-packages pip
# tomli                         2.0.1                 /usr/local/lib/python3.10/dist-packages pip
# toolz                         0.12.0                /usr/local/lib/python3.10/dist-packages pip
# torch                         2.0.1+cu118           /usr/local/lib/python3.10/dist-packages pip
# torchaudio                    2.0.2+cu118           /usr/local/lib/python3.10/dist-packages pip
# torchdata                     0.6.1                 /usr/local/lib/python3.10/dist-packages pip
# torchsummary                  1.5.1                 /usr/local/lib/python3.10/dist-packages pip
# torchtext                     0.15.2                /usr/local/lib/python3.10/dist-packages pip
# torchvision                   0.15.2+cu118          /usr/local/lib/python3.10/dist-packages pip
# tornado                       6.3.1                 /usr/local/lib/python3.10/dist-packages pip
# tqdm                          4.65.0                /usr/local/lib/python3.10/dist-packages pip
# traitlets                     5.7.1                 /usr/local/lib/python3.10/dist-packages pip
# triton                        2.0.0                 /usr/local/lib/python3.10/dist-packages pip
# tweepy                        4.13.0                /usr/local/lib/python3.10/dist-packages pip
# typer                         0.7.0                 /usr/local/lib/python3.10/dist-packages pip
# types-setuptools              67.8.0.0              /usr/local/lib/python3.10/dist-packages pip
# typing_extensions             4.5.0                 /usr/local/lib/python3.10/dist-packages pip
# tzdata                        2023.3                /usr/local/lib/python3.10/dist-packages pip
# tzlocal                       4.3                   /usr/local/lib/python3.10/dist-packages pip
# uritemplate                   4.1.1                 /usr/local/lib/python3.10/dist-packages pip
# urllib3                       1.26.15               /usr/local/lib/python3.10/dist-packages pip
# vega-datasets                 0.9.0                 /usr/local/lib/python3.10/dist-packages pip
# wasabi                        1.1.1                 /usr/local/lib/python3.10/dist-packages pip
# wcwidth                       0.2.6                 /usr/local/lib/python3.10/dist-packages pip
# webcolors                     1.13                  /usr/local/lib/python3.10/dist-packages pip
# webencodings                  0.5.1                 /usr/local/lib/python3.10/dist-packages pip
# websocket-client              1.5.1                 /usr/local/lib/python3.10/dist-packages pip
# Werkzeug                      2.3.0                 /usr/local/lib/python3.10/dist-packages pip
# wheel                         0.40.0                /usr/local/lib/python3.10/dist-packages pip
# widgetsnbextension            3.6.4                 /usr/local/lib/python3.10/dist-packages pip
# wordcloud                     1.8.2.2               /usr/local/lib/python3.10/dist-packages pip
# wrapt                         1.14.1                /usr/local/lib/python3.10/dist-packages pip
# xarray                        2022.12.0             /usr/local/lib/python3.10/dist-packages pip
# xarray-einstats               0.5.1                 /usr/local/lib/python3.10/dist-packages pip
# xgboost                       1.7.5                 /usr/local/lib/python3.10/dist-packages pip
# xlrd                          2.0.1                 /usr/local/lib/python3.10/dist-packages pip
# yellowbrick                   1.5                   /usr/local/lib/python3.10/dist-packages pip
# yfinance                      0.2.18                /usr/local/lib/python3.10/dist-packages pip
# zict                          3.0.0                 /usr/local/lib/python3.10/dist-packages pip
# zipp                          3.15.0                /usr/local/lib/python3.10/dist-packages pip

# %%
import pandas as pd

df_treino = pd.read_csv("/content/drive/MyDrive/ml-dataset/word2vec2/treino.csv")
df_teste = pd.read_csv("/content/drive/MyDrive/ml-dataset/word2vec2/teste.csv")

# %%
df_treino.sample(5)
# Out:
#                                                    title  \
# 14774  Trump defende punir quem queima bandeira ameri...
# 67192  Durante o terremoto, grupo de brasileiros fazi...
# 39003  Tite enumera estatísticas para explicar eficiê...
# 87823  Bill Gates lidera fundo de US$ 1 bilhão para i...
# 11000  Neymar e Cavani se desentendem por cobranças d...
#
#                                                     text        date category  \
# 14774  Qual direito é maior: a bandeira americana, sí...  2016-11-30    mundo
# 67192  Quando o terremoto de magnitude 7.8 atingiu o ...  2015-04-25    mundo
# 39003  São 21 gols marcados em 12 jogos e apenas três...  2016-03-27  esporte
# 87823  O bilionário e filantropo americano Bill Gates...  2016-12-13  mercado
# 11000  Neymar e Cavani se desentenderam duas vezes du...  2017-09-17  esporte
#
#       subcategory                                               link
# 14774         NaN  http://www1.folha.uol.com.br/mundo/2016/11/183...
# 67192         NaN  http://www1.folha.uol.com.br/mundo/2015/04/162...
# 39003         NaN  http://www1.folha.uol.com.br/esporte/2016/03/1...
# 87823         NaN  http://www1.folha.uol.com.br/mercado/2016/12/1...
# 11000         NaN  http://www1.folha.uol.com.br/esporte/2017/09/1...

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# 2023-06-11 15:33:49.441620: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-11 15:33:51.192297: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pt-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.5.0/pt_core_news_sm-3.5.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 78.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-sm==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->pt-core-news-sm==3.5.0) (2.1.2)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
# !ls
# Out:
# drive  sample_data

# %%
import spacy

nlp = spacy.load("pt_core_news_sm")

# %%
texto = "Rio de Janeiro é uma cidade maravilhosa"
doc = nlp(texto)

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc[0]
# Out:
# Rio

# %%
type(doc[0])
# Out:
# spacy.tokens.token.Token

# %%
doc.ents
# Out:
# (Rio de Janeiro,)

# %%
doc[0].is_stop
# Out:
# False

# %%
doc[1].is_stop
# Out:
# True

# %%
textos_para_tratamento = (titulo.lower() for titulo in df_treino.title)

# %%
def trata_textos(doc):
  tokens = []
  for token in doc:
    eh_valido = not token.is_stop and token.is_alpha
    if eh_valido:
      tokens.append(token.text)
  if len(tokens) > 2:
    return " ".join(tokens)
  return None

# %%
trata_textos(doc)
# Out:
# 'Rio Janeiro cidade maravilhosa'

# %%
# %%time
textos_tratados = [trata_textos(doc) for doc in nlp.pipe(textos_para_tratamento, 
                                                         batch_size=1000,
                                                         n_process=-1)]
textos_tratados
# Out:
# CPU times: user 2min 9s, sys: 960 ms, total: 2min 10s
# Wall time: 5min
# ['polêmica marine le pen abomina negacionistas holocausto',
#  'macron le pen turno frança revés siglas tradicionais',
#  'apesar larga vitória legislativas macron terá desafios frente',
#  'governo antecipa balanço alckmin anuncia queda homicídios sp',
#  'queda maio atividade econômica sobe junho bc',
#  'barcelona vence virada atlético madri bate bayern munique',
#  'spartacus oferece duplo retrato batalhas perdidas',
#  'sobe mortos atentado terrorista nice frança',
#  'premiada sundance crystal moselle retrata sexismo mundo skate',
#  'metroviários ferroviários ameaçam parar terça paulo',
#  'anos angeli tirinhas diárias ilustrada',
#  'mortes acidentes trânsito caem cidade sp',
#  'daniel craig será stormtrooper star wars ator',
#  'justiça sp libera construção moradias manancial billings',
#  'prefiro urnas julguem lula achem batom cueca',
#  'olivier anquier transformar cobertura centro restaurante',
#  'mvp nba temporadas steve nash anuncia aposentadoria',
#  'frança nega vinculo terrorista ataque soldados mesquita',
#  'coritiba vence grêmio jogo trapalhada zagueiro gol',
#  'convenção confirmará trump potencial caos',
#  'subgênero funk proibidão metáforas falar crime',
#  'criador virada cultural josé mauro gnaspini tocará cultura olimpíada',
#  'jon snow volta holofotes vídeo temporada game of thrones',
#  'ceni testes bola sente dores segue dúvida sábado',
#  'jogo brasileiro tv fechada recorde público',
#  'corintianos dividem vaiar ignorar guerrero itaquerão',
#  'polícia federal oferece passaporte caro furar fila atraso',
#  'modelo reflexo filosofia mclaren',
#  'refaria filmes afirma woody allen cannes',
#  'remake anos raízes narra saga família escravos eua',
#  'embaixador emolândia morrissey show sentimental sp',
#  'israel condenado prisão corrupção',
#  'raízes romantismo prazer intelectual garantido',
#  'tela igual xeque autenticidade volpi chico buarque',
#  '',
#  'invicto corinthians tenta voltar vencer paulista',
#  'prefeitura recolhe cerca t resíduos réveillon rio',
#  'setecentas pessoas recebem seleção temuco copa américa',
#  'elite intelectual perdeu rio considera moralmente superior',
#  'gravações mostram técnicas venda carnes podres proibidas',
#  'israel prima torce bernie sanders chegue casa branca',
#  'chamado pressas acriano weverton histórico pegador pênaltis',
#  'netanyahu desculpa declaração árabes feita dia eleições',
#  'parque olímpico acumula pendências obras segurança',
#  'desalento endorfina drogado multidão',
#  'hoje tv leicester chelsea campeonato inglês',
#  'haddad libera fechamento vilas ruas saída sp',
#  'obra banksy critica tratamento imigrantes coberta londres',
#  'doria manter padrão pista marginal',
#  'ministério público pede suspensão organizadas vasco fluminense',
#  'obesidade antibióticos microbioma',
#  'médicos completa anos mudar regra fixar brasileiros',
#  'franquia hostel cresce onda hipster',
#  'twitter suspende perfis plano russo ajudar trump eleger',
#  'chuva eleva rios campinas restrição captação descartada',
#  'criada há anos gravadora daptone records revigorou estilo eua',
#  'schweinsteiger processar empresa boneco nazista parecido',
#  'temporal deixa mortos provoca estragos sc ficam luz',
#  'obra liberar pista marginal tietê entra fase',
#  '',
#  'música batuque mães fundação casa ampliam vínculo bebê',
#  'luzes pista congonhas fecha hora meia paulo',
#  'protestos corrupção derrubam ministro justiça romênia',
#  'remédios ofertados decisão justiça sus',
#  'diretor americano bob wilson planeja peça mané garrincha',
#  'anatel afirma geração caixa oi garante operação',
#  'terror incêndio brexit levam caos medo política britânica',
#  'brigada militar mata homens tentavam invadir delegacia rs',
#  'karatê kid ganha sequência ralph macchio kid',
#  'thiago braz concorre prêmio melhor atleta ano atletismo',
#  'mauricio galiotte eleito presidente palmeiras',
#  'defensor acesso informação criador wikipédia paulo',
#  'chefe uber reino unido deixa cargo empresa tenta evitar proibição',
#  'qatar volta rejeitar exigências nações árabes mantêm boicote',
#  'kodaline substitui sbtrkt lollapalooza nofx cancela turnê',
#  'sessão grátis peça músicas milton nascimento despede',
#  'horas pescadores encerram bloqueio transatlântico sc',
#  'turner compra tv aberta clubes encontrarem interessados',
#  'programação completa festival boticário dança',
#  'morre cineasta francês françois dupeyron anos',
#  'crítico kirchner el ciudadano ilustre encerra festival rio',
#  'marisa monte paulinho viola farão série shows juntos capitais',
#  'eletrobras seguir petrobras executivos mercado ministro',
#  'veto entrada imigrantes eua suspenso decisão judicial',
#  'medalha ouro rio',
#  'fases disruptivas apple inova adaptação criativa',
#  'devemos celebrar decadência expressão risco morte',
#  'planta tomates colherá tomates',
#  'morte inesperada prince voltar topo lista billboard',
#  'brasileira fica presa dias rússia visto expirado',
#  '',
#  'livro ensina encontrar trabalho ideal lançamentos',
#  'erramos empurradores ajudam cadeirantes corridas rua',
#  'frança começa transferir crianças jovens campo calais',
#  'obras culturais britânicas revelam traços rejeição estrangeiros',
#  'bloqueio whatsapp pessoas redescobrem vida aplicativo',
#  'disputa futuro carro autônomo fica acirrada',
#  'página louva tradições cultura subúrbios cariocas',
#  'turquia afasta militares expurgo frustrado',
#  'maria inês dolci marco civil cuidados regulamentação',
#  'governo rio investiga suspeita surto malária região serrana',
#  'justiça absolve banco santos ação sonegação',
#  'andamento medidas governo temer',
#  'bandeira pobreza vocabular marcador sofisticado',
#  'há momentos história riso',
#  'bandiera rossa toca',
#  'título suspeito gestão ascensão rival paulo',
#  'sindicato reunião governo macri atenua ameaça greve',
#  'casal encontrado morto tiros hotel luxo região central sp',
#  '',
#  'chavismo mostra supostas provas plano golpe',
#  'iniciativa mundial encontros falar morte ganham espaço sp',
#  'bomba eua afeganistão eleva tensão bolsa cai dólar sobe',
#  'chefe máfia resultados encontrado polícia',
#  'fazenda barretos sp defende giro capital atrair pecuaristas',
#  'diego costa sofre lesão empate chelsea parar hospital',
#  'folha recebe prêmio categoria melhor site comunicação',
#  'gaby amarantos condena intolerância festival cultura inglesa',
#  'bc bangladesh fecha investigação empresa eua ação hacker',
#  'cidade paulo terá luzes led julho',
#  'cbf rompe patrocinador muda plano saúde campeões mundiais',
#  'corpo belchior chega fortaleza será sepultado',
#  'furacão harvey eua petrobras elevar preço gasolina',
#  'globo exige preparação elenco novelas',
#  '',
#  'grafite marca líder santa cruz goleia cruzeiro',
#  'divertida mente tons melhor pior cinema',
#  'esnobar academia sueca bob dylan cerimônia obama',
#  'advogados abandonam defesa principal suspeito ataques paris',
#  'azul cor quente kechiche esquenta veneza',
#  'alckmin perillo defendem reforma previdência servidor público',
#  'empresas aéreas padrão mundial bagagem mão',
#  'disparos tentativa assalto zona sul rio deixam feridos',
#  'pombal royal society',
#  'francisco xavier recebe encontro mantiqueira',
#  'cirurgia joelho alison recuperar perdido santos',
#  '',
#  'madonna vence processo violação direitos autorais canção vogue',
#  'rogue one arrecada mi bilheteria semana estreia',
#  'bolsa cingapura negocia compra londrina baltic exchange',
#  'criança eletrocutada passar roleta estação ônibus brt rio',
#  '',
#  'diretor vw empresa recuperar confiança',
#  'rodolfo lucena erro corrida leva maratonista colapso chega engatinhando',
#  'incêndio portugal mão criminosa chefe bombeiros',
#  'pm pessoas mortas tiros gonçalo rio',
#  'judô garante primeiras medalhas brasil pan toronto',
#  '',
#  'criminoso morre acidente durante tentativa assalto taxista sp',
#  'prefeitura regional sé concentra autuações cidade ano',
#  'anp deixa monitorar qualidade gasolina estados df',
#  'problema brasil político econômico professora harvard',
#  'safra brasileira berlim viaja espaço',
#  'chuva forte vendavais atingem sul país pessoas morrem sc',
#  'cidade paulo volta fria ano',
#  'eua cérebro músculos',
#  'alalaô ministério saúde distribuirá milhões camisinhas carnaval',
#  'denúncia temer prejudicar nota crédito brasil agência',
#  'temer pede empresários priorizem formados exterior',
#  'robinho exames joelho poupado treino seleção',
#  '',
#  'casa paulo perde time série c complica copa brasil',
#  'nacional investe bilhão parques eólicos maranhão',
#  'mortes cansava desenhar ensinar',
#  'queremos cool afirma flea red hot chili peppers',
#  'wall street forte queda petróleo china',
#  'hbo renova westworld planeja exibir temporada',
#  'importados ganham espaço produção indústria',
#  'incertezas frança lembra ataques charlie hebdo ano',
#  'estendida dias trégua aleppo leva ajuda civis sitiados',
#  'sábado sol paulistanos churrasco passeiam minhocão',
#  '',
#  'vítima sequestro relâmpago escapa carro suspeitos presos sp',
#  'crise pec domésticas acelerar mudança cultural mercado trabalho',
#  'convergência inesperada unir contrários',
#  'rússia voltar palco título construtores mercedes',
#  'retorno abaixo inflação poupança perde recursos',
#  'presidente chilena propõe ampliação aposentadorias país',
#  'temer flexibilizará voz brasil durante jogos olímpicos',
#  'declarações ofensivas ibrahimovic serão investigadas liga francesa',
#  'wet hot american summer netflix apela nostalgia',
#  'oficializar pedido saída sérgio corrêa',
#  '',
#  'brasil países oea consideram saída venezuela recurso',
#  'randy newman candidato oscar destaca festival caribenho',
#  'ministro pôs tarjas nomes lula marina processo tse',
#  'erramos casal gay brasileiro enfrenta preconceito irlanda',
#  'rio perde espaço desbanca sp metrópoles',
#  'despoluição baía vira novela olímpica',
#  'nadadora quebra recorde m livre ratifica vaga',
#  'mcdonald transfere reino unido sede fiscal atividades eua',
#  'republicanos acusam democratas incorretamente durante convenção',
#  'crise rússia anuncia corte gastos copa',
#  'ricardo gomes mistério define equipe clássico',
#  'guerra única alternativa acordo irã aprovado obama',
#  'silvio santos exibe paródia trata roberto marinho hitler',
#  'carro jovens fuzilado militares rio',
#  'anos clarice falcão retoma carreira musical prepara álbum',
#  'manifestantes fogo pneus bloqueiam avenida zona leste sp',
#  'procure gil chico caetano opõe ecad supremo',
#  'delação joão santana detalhar despesas pagas dilma rousseff',
#  'lollapalooza terá noel gallagher eminem confira',
#  'brasil perde canadá disputa bronze basquete feminino',
#  'renato augusto desabafa achou jogaria alto',
#  'pm mata suspeitos tentativa furto banco ribeirão preto',
#  'dólar cai bc eua manter juros bolsa recua',
#  'cineasta israelense amos gitai injeta política festival veneza',
#  'evoca banksy sarah kane dança usp',
#  'fases planos previdência',
#  'oca obras itaú cultural tentam retratar extremos brasil',
#  'brasil supera alemanha ranking construções sustentáveis',
#  'brazil successful organisation of rio considered more important than their sporting prowess new survey reveals',
#  'vamos interessa reúne cem crônicas joão pereira coutinho',
#  'açougues mercados descumprem regras vigilância sanitária',
#  'show eua julian casablancas confirma álbum strokes',
#  'crítica whiplash explorar alma personagens',
#  '',
#  'banqueiros temem avanço aumento regulação financeira',
#  'ingressos esgotados filarmônica viena traz excelência paulo',
#  'carrinhos supermercado gigantes tomam sp intervenção artística',
#  'livro memórias cárcere retraça escrita proposta obra',
#  'coreia sul volta retoma compra carne frango brasil',
#  'bloqueio aplicativos banalizado deputados cpi',
#  'obama cobra palestra bancos wall street',
#  'semana tv mistério dilema moral comemoração óbvia páscoa',
#  'senado aprova medida provisória doping isenção fiscal olimpíada',
#  'cracolândias crescem centro sp viram favelinhas',
#  'eleição presidencial portuguesa pede aliança esquerda',
#  'soninha assume namoro rua difícil',
#  '',
#  'propaganda ivete sangalo será investigada tirar sarro homens',
#  'sobe nº desabrigados cheia histórica capital acre',
#  'warriors vence cavaliers abre vantagem finais nba',
#  'porta entrada olimpíada galeão pior avaliação aeroportos',
#  'cadeia bahia presos cerveja churrasco',
#  'estudante internado sofrer agressão ato goiânia',
#  'orleans obama elogiará união',
#  'herdeiro samsung preso suspeito elo corrupção coreia sul',
#  'procurador pede milhão dano trabalhadores obra petrobras',
#  '',
#  'saco cheio ny jim jarmusch refugia casinha estreia paterson',
#  'protestos extremismo islâmico reúnem centenas austrália',
#  'última esperança brasil bruno soares eliminado austrália',
#  'ação abuso sexual eua mobiliza obama lady gaga',
#  'barça pega bayern reencontrar guardiola real encara juventus',
#  'motim presídio minas termina feridos quase horas',
#  '',
#  'eua julgarão policiais ligados morte negro baltimore',
#  'frança urnas aposentaram elite política fabricaram',
#  'protesto moradores cidade deus fecha linha amarela rio',
#  'assalto termina feridos rua laranjeiras zona sul rio',
#  'john mayer anuncia shows brasil outubro',
#  'ação petrobras atinge tombo petróleo',
#  'hoje tv tigres mex x internacional libertadores',
#  'indicada globo ouro casual surpresa diretor juno',
#  'pm desculpa impedir criança entrar allianz rosto pintado',
#  'câmara eua abusou crianças promotoria',
#  'comissão aprova estatuto define família união homem mulher',
#  'polícia apreende kg drogas chácara alto padrão sp',
#  'google concorda pagar mi resolver disputa fiscal itália',
#  'aplicativo alertas retira moradores rotas balas perdidas rio',
#  'corinthians santos preso acusado furto qualificado',
#  'grêmio internacional sobe brasileiro',
#  'pequim convoca embaixador eua navio cruzar águas disputa',
#  'reforços arma juventus jejum liga campeões',
#  'gênio galã edward frenkel matemática cool',
#  'receita federal arrecadar previsto autuações',
#  'alalaô bloco guenta começa agitar carnaval chapada guimarães',
#  'reconstrução custará bilhões equador calcula governo',
#  'cães lambem transtornos psicológicos',
#  'poupatempo luz deixa prédio polícia sp será reformado',
#  'debate ambiental urgente',
#  'banco brasil pede esclarecimento cbv contratar acusado desvio',
#  'rapper americano chinx morto tiros eua anos',
#  'júri osasco rompe barreira condenar policiais megachacina',
#  'apesar maniqueísmos dias evita panfletário',
#  'fizemos musical tamanho gente jorge fernando vamp',
#  'mortes encontrou amor vida correios',
#  'embaixador russo central controvérsias governo trump',
#  'segurança exige houthis deixem iêmen',
#  'original astérix vendido benefício charlie hebdo',
#  'par bill murray sigourney weaver retorna',
#  'governo acena correção tabela',
#  'júri absolve policiais highlanders acusados decapitar deficiente sp',
#  'atentados diminuem chance integração muçulmanos',
#  'gorros bichinho viram moda hipsters aquecer virada',
#  'samarco entrega versão plano recuperação ambiental ibama',
#  'flexibilidade planejamento urbano fundamental futuro cidades',
#  'manchester united perde casa cai inglês',
#  'dia tomorrowland piscina atrações disputadas',
#  'rico americano compra papel higiênico barato pobre',
#  'la paz seleção ganhou jogo comportamento covardia geográfica',
#  'paulo jogo peso decisão dias',
#  'jean wyllys relata ameaças morte família rastreada',
#  'guia fritando doutora dilma',
#  'justiça pernambuco suspende liminar revogava reajuste tarifa ônibus',
#  '',
#  'poesia jodorowsky atinge sublime infame',
#  'derrota hillary fundação clinton reexamina perspectivas',
#  'jogo viradas inter vence emelec libertadores',
#  'espera concessões demanda queda travam escolha hub latam',
#  'trumpcare oposto trump republicanos prometeram',
#  'crimes ficha homem preso estupro avenida paulista',
#  'ben affleck desiste dirigir batman previsto',
#  'força mulher tema mostra galeria houssein jarouche',
#  'joão gomes júnior prata pódio natação brasil mundial',
#  'retorno jon snow game of thrones decepcionou kit harington',
#  'dólar alto incentiva criação aplicativos comparar taxas',
#  'casos dengue aumentam sp morte sendo investigada',
#  'mercadante defende gramática currículo nacional educação',
#  '',
#  'tempestade neve deixa mortos feridos japão',
#  'temer gastar dilma',
#  'suprema corte eua derruba sigilo júri viés racista',
#  'justiça venezuelana emite decisão complica referendo maduro',
#  'igreja charleston realiza cerimônia religiosa massacre',
#  'mostrar futebol mundo xodó palmeiras gabriel jesus',
#  'congresso eua analisar acordo nuclear irã',
#  '',
#  '',
#  'oriente médio trump desafiar países visão pacífica islã',
#  'ano protagonista psi sai consultório busca casos ruas',
#  '',
#  'governo discutir fatia repatriação estados meirelles',
#  'biografia retrata pai dumas inspirou conde monte cristo',
#  'banco antigo mundo tenta levantar bi evitar resgate itália',
#  'pfizer compra fabricante remédio câncer bilhões',
#  'dilma governo lista janot',
#  'senhor brasil celebra sala sp anos',
#  'morre marco antonio mastrobuono colecionador especializado volpi',
#  'augusto campos descobre pérolas fundo oceano',
#  '',
#  '',
#  'fraudes licitações pm usavam assinatura motorista',
#  'brasil exportou vírus zika itália',
#  'epe adia início operações usinas hidrelétricas rio tapajós',
#  'concessionária luxo oferece vacina gratuita gripe',
#  'euforia título corinthians toma quadra gaviões vila madalena',
#  'abstração revista livro',
#  'medalhista olímpico cair diego hypolito',
#  'tribunal contas manda empresas taparem buracos paulo',
#  'cientistas deveria transferida adiada causa zika',
#  '',
#  'renato augusto jogo ofensivo abertura olimpíada',
#  'queda indústria vira vilã renda brasil',
#  'principal fabricante cerveja venezuela suspende produção',
#  'anos bicampeã mundial fabiana murer confirma aposentadoria',
#  'saída feriado prolongado deixa trânsito acima média paulo',
#  'despedida criador downton abbey considerar filme série',
#  'dólar bate recua grécia brasil radar bolsa oscila',
#  'china feirão petrobras',
#  'há detalhar policiais delegacia alckmin',
#  'terminais gás petrobras operam metade capacidade',
#  'mortes abrigo época ditadura encobertas coreia sul',
#  'ciclovia asfaltada há zona oeste sp segue apagada',
#  'china presenteia cidade alemã marx nasceu estátua filósofo',
#  'governo editará portaria regras fiscalização cultura',
#  'objetos mad men leilão internet',
#  'idade diferente aposentar compensa desigualdade gênero',
#  'dilma cai maduro perde',
#  'desequilíbrio atuações prejudica travessia',
#  'brexit judeus britânicos procurem cidadania alemã',
#  'hoje vou bater ratoeira',
#  'economistas veem inflação contração pib',
#  'grato ricardo oliveira renovar santos salário triplicar',
#  'paulo anuncia contratação cícero temporadas',
#  'mubarak solto determinação justiça egito',
#  'obama pede policiais tenham tolerância respeito',
#  'promotoria pede prefeito caracas preso receba tratamento',
#  'ford testa veículo autônomo fala pedestres sinais luz',
#  'ecad terá dias atualizar critérios cobrança direitos autorais',
#  'apesar proibição público leva pau selfie lollapalooza',
#  'bandidos explodem caixa eletrônico estádio morumbi',
#  'indústrias preparo explorar revolução digital',
#  'taxa média juros cartão crédito supera agosto ano',
#  'jogadores manchester united lutando van gaal rooney',
#  'análise clima violência adoecendo profissionais saúde',
#  'viva frança produção caprichada ousadia',
#  'instrumentos pesca descartados oceano lixo marinho',
#  'processo temer sobrevirá',
#  'vitória governo reforça apostas investidores queda juros',
#  'infelizmente atentado previsível afirma marine le pen',
#  'acidente escolar deixa mortos tanzânia',
#  'gol volante palmeiras vence xv piracicaba jogo matutino',
#  'pior gabar abertamente fingindo humildade',
#  'cbf diminui preço ingresso estádio cheio jogo seleção ba',
#  'eletricista cadeira rodas cães recebe lambidas gratidão',
#  'mortes confronto polícia aumentam fevereiro rio',
#  'al qaeda planeja ataques escala ocidente chefe',
#  'oposição áfrica sul elege líder negro história',
#  'vila velha pedras menores morro vista serão retiradas',
#  'trailer documentário cantora nina simone',
#  'volta corinthians malcom ataque love luciano',
#  'reações rede revelação lais souza incredulidade',
#  'câmara comuns britânica aprova turno negociações brexit',
#  'maoísmo sabor camembert',
#  'opinião ataque levantar debate indústria guerra',
#  'frente fria paulistano terá sábado gelados garoa',
#  'professores colégios particulares dia reformas temer',
#  'máquina pmdb ficou aberto novidades',
#  'demanda oferta voos domésticos recuam novembro associação',
#  'rússia piloto jato abatido turquia resgatado',
#  'tiroteio boate deixa pessoas feridas arkansas',
#  'mi douglas costa deixa shakhtar acerta bayern',
#  'marina and the diamonds brilha lolla compensa fãs bolo',
#  '',
#  'protesto liberação uber taxistas fecham maio',
#  'procuradoria suíça obteve evidências fifa denúncia',
#  'cidades sp casos dengue superam',
#  'venezuela arábia saudita discutem cooperação produtores petróleo',
#  'telefónica apresentar plano reduzir dívida moody',
#  'faça make sereia lantejoula glitter',
#  'game of thrones bate recorde audiência episódio reestreia',
#  'petróleo baixa adiar leilão ministro',
#  'polícia investiga venda irregular ingressos comitês olímpicos',
#  'emoções juliette binoche evaporam papel empatia',
#  'impeachment temer prepara combater críticos',
#  'protestos violentos taxistas adotam tática paz amor',
#  'chuck berry gênio inventou adolescência',
#  'fabiana murer quebra recorde melhor marca ano',
#  'real madrid bate sevilla abre vantagem liderança espanhol',
#  'cartas frida kahlo revelam intimidades vida apaixonada',
#  'jovem esfaqueado morre praia ipanema rio',
#  'justiça sp permite suzane von richthofen volte regime semiaberto',
#  'obama recebido mauricio macri dia visita argentina',
#  'luz causa queda árvores moradores butantã ficam isolados',
#  'brasil méxico barbárie',
#  'peça única look dilma posse feito pressas',
#  'kazuo ishiguro autor vestígios dia ganha nobel literatura',
#  'loucos aviões fotografam pousos decolagens pista aeroporto',
#  'razão sucesso mexicano hollywood união diretores',
#  'anp investiga petroleiras suspeita subfaturamento notas',
#  'libertadores abole semi forçada times país regras',
#  'recuperar construtora tenda mudou erguer edifícios',
#  'confira filmes ajudam entender economia',
#  'brasil leva gol mão perde peru eliminado copa américa',
#  'lucro bndes aumenta trimestre chega bilhões',
#  'itália enviará missão negócios brasil impeachment premiê',
#  'restaurantes entram front debate imigração eua',
#  'milhares ruas guatemala pedir renúncia presidente',
#  'volume coleção folha pequena sereia chega bancas domingo',
#  'vereadores sp aprovam uso portões fechar ruas saída',
#  'travestis combatem jair malafaia eduardo feliciano filme',
#  'jesse eisenberg busca sorte café society woody allen trailer',
#  'brasil outrora engraçado movido azedume',
#  'carnaval acaba país volta dançar',
#  '',
#  'pagar prêmio milhões sorteio sábado',
#  'festival glastonbury multado vazamento esgoto rio',
#  'trabalhar sobreviver será necessário empreendedor',
#  'parentes vítimas sentem angústia raiva desastre aéreo egito',
#  'olho invepar canadense socorre oas milhões',
#  'rio janeiro vanguarda atraso sérgio rodrigues flip',
#  '',
#  'chinês negocia controle banco indusval agência',
#  'governo monitora cem suspeitos simpatia terror brasil',
#  '',
#  'flamengo empata perde chance assumir liderança estadual rio',
#  'exortação amor papa francisco defesa tolerância',
#  'virtude construir flutuações sentimentos familiares',
#  'mercado jornalismo explique fatos amplo fundador vox',
#  'toffoli pede adiamento votação doações privadas políticos',
#  'projeto lei legaliza cassinos avança parlamento japão',
#  'temer china assombrado lorotas',
#  'crise migratória ecoa passado hungria',
#  'parlamento europeu avalia crédito manter serviço público grego',
#  'símbolo feminismo dayse masterchef',
#  'promessa periferia trava paulo',
#  'torre eiffel paris exceção monumentos famosos',
#  'economistas ajuste fiscal deixar recessão',
#  'salário mínimo visa agradar base dilma aquecer economia',
#  'navegar dias hoje',
#  'ônibus rápido solução afirma ny sp',
#  'cristina kirchner ocultou mi transferências afirma jornalista',
#  'morre derek walcott poeta caribenho nação',
#  'única brasileira mundial surfe estreia atual campeã',
#  'odebrecht pagou milhões propina colômbia procurador',
#  '',
#  'pianista abdullah ibrahim show jazz fábrica',
#  'design serviço curador mostra produção brasil',
#  'série bolsa ensina tomar cuidado promoções enganosas',
#  'escrever morrer inglesa brasileira praticantes poesia falada',
#  'atletas artistas pagar impostos ajuste fiscal',
#  'paulo terá show daniela mercury quase blocos',
#  'concentra imigrantes pobreza industrial',
#  'ueba aranha tá dengue',
#  'falha milagre nápoles vista prenúncio tragédias',
#  'adnet seremos medida receber feito',
#  'história brasil conhecemos fantasia cientista político',
#  'desemprego procura criação vagas',
#  'hoje tv gp rússia fórmula',
#  'senado aprova veto cobrança bagagem texto segue câmara',
#  'olho mercado explorado franquias favelas',
#  'ato aumento tarifas termina quebradeira confusão paraná',
#  'crítica escritos mostram ivana arruda leite texto afiado',
#  'prefeitura santos reduz preço museu pelé temer prejuízo',
#  'jennifer lopez leva hillary palco show miami pede votos',
#  'câmara ignora governo aprova possibilidade reaposentadoria',
#  'polícia usuários drogas entram confronto cracolândia sp',
#  'filme amos gitai produção nazismo destaques tv semana',
#  'ministério planejamento propor meta fiscal flexível',
#  'turista sp encontrado morto piscina hotel recife',
#  'palestinos mortos ataques jerusalém cisjordânia',
#  'garimpo ilegal ouro leva milhares reserva ambiental amazonas',
#  'kid vinil ensinou famintos',
#  'divorciado bilionária doda divide cavalo usará jogos',
#  'ausência russa atletismo sentida esperado',
#  'acidente ônibus empresa colitur paraty causa mortes',
#  'lavoura trigo entra fase crítica paraná',
#  'filho renato russo doar objetos pai retiro artistas',
#  'livro jornalista jeannette walls revela infância conturbada',
#  'análise ataque frança liberdade imprensa xeque',
#  'caixa eleva limite financiado imóvel usado',
#  'críticas digno lovelace oposto pensa pornôs',
#  'espetáculo privilegia dança tradicional índia bollywood',
#  'irmão suspeito ataques paris recusou explodir',
#  'homem preso apagar tocha olímpica balde ms',
#  'consumidores pagarão compensação hidrelétricas uso usina térmica',
#  'stone pagamentos compra elavon empresa máquina cartões citi',
#  'egito deixa considerar hamas organização terrorista agência notícias',
#  'conta luz terá bandeira amarela julho custo adicional aneel',
#  'fantasmas temer carne osso',
#  'receita exigir cnpj informação donos offshores trusts',
#  'estátua borba gato monumento bandeiras pichados sp',
#  'alisson jefferson mostrou caráter barrado admite frustração',
#  'paletó azul brilhante elton sobe animadíssimo palco rock in rio',
#  'narrativa superficial rainha neve descamba brega',
#  'trump pence mesma chapa',
#  'ferramentas mapeiam consumo escolher comercial',
#  'futebol ouro rafaela judô despertam feminismo redes sociais',
#  'gol tevez juventus bate lazio aproxima título',
#  'ericsson eleva previsão gastos reestruturação cortes suécia',
#  'yahoo vendido operadora americana verizon bilhões',
#  'crimes ódio hiv lutas estereótipos mundo boxe lgbtt',
#  'evocar morte why the horse maria alice ode',
#  'novidades retorno gilmore girls agradar fãs',
#  'campeonato francês usará tecnologia linha gol temporada',
#  'justiça determina quebra sigilo maestro john neschling',
#  'soldados acham corpos cidade retomada boko haram',
#  'índice motoristas alcoolizados blitze despenca paulo',
#  'el comité río va distribuir repelentes atletas y voluntarios',
#  'rolling stones provocam fãs redes sociais prometem anúncio',
#  'concilia enxada salto alto vira miss sul',
#  'fake news conceito popularizou perde sentido',
#  'ganho carteira líder simulador ações cai',
#  'ação incendiária trump aprofunda dilemas europa',
#  'gol lucro consecutivo câmbio resultado operacional melhor',
#  'festival documentários verdade abre inscrições',
#  'mundo virtual paisagem surpreende viajante',
#  '',
#  'tragédias anos deram origem futebol inglês atual',
#  'legião urbana voltará formação dado',
#  'campeão palmeiras contratações pontuais',
#  'torcedores apoiam alemão boateng comentário racista',
#  'recuperações judiciais explodem alertam bancos',
#  'curiosidades jovem guarda anos agosto',
#  'pressão republicanos imprensa donald trump efeito dúbio',
#  'mancha verde muda sede retira boneco símbolo fachada',
#  'diretor tv morre tiro acidental filho',
#  'erramos eduardo suplicy será secretário haddad',
#  '',
#  'racismo crise econômica ibérica regem filmes festival berlim',
#  'tesouro nega haver fuga investidores títulos públicos',
#  'meia emprestado santos vitor bueno decide time semifinal',
#  'escracho coletivo apresentador anarquizou showbiz',
#  'sessões esgotarem corpo abre apresentações gira',
#  'casos assédio sexual caem justiça sp',
#  'dependemos arte francesa viciado drogas sokurov',
#  'empoderamento feminino clichê constrangedor washington olivetto',
#  'juros financiamento casa parcela',
#  'agente serviço secreto preso eua enviar fotos nu adolescente',
#  '',
#  'ministry vence mortes drogas tocar país',
#  'justiça proíbe demissão fundação gaúcha negociação sindicatos',
#  'carro elétrico começa superar limite baterias',
#  'leituristas contas luz df ajudam identificar focos aedes',
#  'crítica antídoto moda artificial',
#  'torcedores invadem campo comemorar classificação time inglês',
#  'economistas apostam alta juro básico ano semana',
#  '',
#  'eagles of death metal público trocam declarações amor lollapalooza',
#  'hoje tv série b brasileiro amistoso internacional futebol',
#  'brasileiro segura gastos apostas loteria',
#  'órgãos audiovisual defendem regulamentar netflix afins',
#  'neymar galvão muda pra paris',
#  'símbolo gestão varrição rua recua doria',
#  'governador rio sanciona lei proíbe porte facas',
#  'testemunha grava vídeo corpos ataque nice imagens fortes',
#  'bombas caem hospitais centro distribuição síria',
#  'caixa perde mercado crédito habitacional',
#  'análise pressão felipe nasr mostra cartão visitas',
#  'painel fc torcida única assentos palmeiras calcula lucro extra milhão',
#  'roubos voltam crescer vítimas homicídios estabiliza sp',
#  'série mostra porta adentro windsor',
#  'coreia norte fracassa tentativa lançar míssil pentágono',
#  'belo horizonte interdita parque suspeita febre amarela macaco',
#  'miriam belchior assumir presidência caixa',
#  'trump jamais será presidente george clooney festival cannes',
#  'neymar marca gol barcelona ajuda golear granada',
#  '',
#  'deficiências ganha virtudes perde esquecidas',
#  'stj concede habeas corpus sininho manifestantes',
#  'investidor volta mirar juro alto emergentes',
#  'ronaldo cala vaias moscou vitória portugal rússia',
#  'erramos ministro petrobras transparência absoluta',
#  'maracanã passará reformas olimpíada nuzman',
#  'bando hospeda resort manaus anuncia assalto leva refém',
#  'dólar ronda estabilidade olho juros eua política brasileira',
#  'filme sangue azul celebra amor livre fantasia espetáculo',
#  'greve organizadores esperavam governo gostaria cientista político',
#  'robert niro volta ringues treinador drama punhos aço',
#  'polícia prende suspeitos tráfico operação cracolândia sp',
#  'legado günter grass comparável goethe ministra alemã',
#  'temer paga caro vitória custo subir denúncia',
#  '',
#  'aquarius indicado spirit awards oscar cinema independente',
#  'daniel dias conquista ouro segue busca marca histórica',
#  'multitela telecine exibe filme feito hector babenco',
#  'trump fio ignorância obstrução justiça',
#  'burocracia irrita classe média chinesa',
#  'rio aposta aplicativo combater crime',
#  'caça força aérea cai base zona oeste rio pilotos sobrevivem',
#  'ônibus expressos gp custarão',
#  'ameaça csn obtém licença barragem complexo casa pedra',
#  'câmara aprova reajuste judiciário funcionalismo',
#  '',
#  'aretha franklin juanes cantarão papa filadélfia',
#  'governo relator finalizam proposta previdência',
#  'rio janeiro praias lotadas sábado ano',
#  'leia íntegra discurso dilma onu metas ambientais',
#  'carreta carga superdimensionada retirada avenida sp',
#  'criador japan house madeira concreto arquitetura',
#  'memorioso formigueiro mental',
#  'consuelo única geração manter sangue olhos',
#  'caetano arnaldo antunes tom zé unem tributo augusto campos',
#  'emocionante arqueólogos ressalta grandeza ínfimo',
#  'valongo festival leva fotógrafos pensam questões raciais santos',
#  'gusttavo lima perde direito cantar música fiz',
#  'temer sanciona lei distribuição gorjeta taxa serviço',
#  'dias itália resgata barco deriva imigrantes bordo',
#  'moreira franco concessões paradas devido lava jato',
#  'miss brasil recebeu proposta book rosa',
#  'trecho desocupado lago paranoá aberto público brasília',
#  'fla estreia prodígio empata abertura brasileiro',
#  'manhattan selfies colocaram congresso americano alerta',
#  'derrota anderson silva volta outro modelo preparação',
#  'esporte olímpico preocupa virá jogos',
#  'volta minc reforça compromisso temer cultura ministro',
#  'melhor novato austrália nasr fala alívio corrida emocionante',
#  'rio janeiro voltar antecipar royalties petróleo pezão',
#  'bauza ausência michel bastos decisão técnica',
#  'levy investidores londres desaceleração brasileira temporária',
#  '',
#  'inadimplentes somam milhões brasil',
#  'baixista black sabbath preso briga bar califórnia',
#  'bulls vencem acabam sequência triunfos spurs nba',
#  'vereador entra pedido cpi investigar desvios municipal',
#  'polícia encontra corpo criança morta jacaré disney',
#  'lula manipulação radicalismo',
#  'apesar entraves legais biografia roberto carlos entra disputa',
#  'brasileiro chega maratona sp quenianos dominam competição',
#  'economistas manifesto diploma obrigatório',
#  'produtores usam documentos falsos aprovar maysa lei rouanet',
#  'vencedor verdade mostra reencontro pai filho copa',
#  'produção petróleo russa atinge março quase anos',
#  'dunga começa treinos copa américa cargo ameaçado',
#  'homem suspeito matar frente filho anos sp',
#  'estúdio amélie poulain pulp fiction vendido qatar',
#  'alemanha recusou pessoas ano',
#  'súmula árbitro ignora expulsão anulada jogo palmeiras',
#  'espanto votou pmdb',
#  'rio janeiro negociar recuperação governo',
#  'estreia samira makhmalbaf maçã exibe força iraniana',
#  'prefeito osasco decide sair pt',
#  'vitória osorio lamenta desempenho paulo',
#  '',
#  'distribuidora inicia projeto gasoduto milhões bahia',
#  'motorista enfrenta lentidão rodovias paulo',
#  'almodóvar cancela promoção filme panama papers',
#  'aneel eleva preços leilão energia solar eólica novembro',
#  'redução preço gasolina chega consumidor',
#  'windows microsoft atrair criadores apps',
#  'zika espalhar costa golfo eua especialista',
#  '',
#  'liminar justiça determina banda sinfônica preservada',
#  'douglas costa principal aposta dunga seleção peru',
#  'netflix produz alias grace minissérie baseada livro margaret atwood',
#  '',
#  'corinthians encontra vazamento itaquera teme deslizamento',
#  '',
#  'cooperativas crédito investir milhões ano',
#  'ataque missão paz onu mali deixa mortos feridos',
#  'pm vítima preconceito secretário segurança alckmin',
#  '',
#  'gestão haddad reduz previsão investimentos paulo',
#  'policiais eua encaram duplo papel vilão vítima',
#  '',
#  'brunoro fecha santos cuidar planejamento',
#  'medalha medalha medalha',
#  'temer dilma lamentam atentado boate gay orlando',
#  'peça alessandra negrini evoca fantasmas legado bandeirante',
#  'mpl reunião governo promotoria discutir protestos',
#  'arrecadação previdência privada cresce semestre',
#  'joão doria proibir uber táxi autorizar limusines',
#  '',
#  'coral une vozes conflito',
#  'bater recorde murer conquista bronze liga diamante',
#  'ovacionado torcida ronaldinho treino fluminense',
#  'polícia russa prende ativistas gays tentavam protestar petersburgo',
#  'porta zorra mudar bobo ian sbf',
#  'tarifa ônibus intermunicipais terão aumento domingo sp',
#  'avião militar russo bordo cai mar negro há sobreviventes',
#  '',
#  '',
#  'dalton trevisan rubem fonseca completam ativos décadas vida',
#  'emocionante iraquiano revê mãe ônibus refugiados',
#  'show messi barcelona goleia segue cola real madrid',
#  'obama recusa enviar tropas combater islamitas somália',
#  'secretário aviação pretende colocar viracopos venda ano',
#  'haitianos urnas domingo apuração iniciada luz velas',
#  'mau gosto expõe beleza expressão força',
#  'paulo terá ônibus poluentes',
#  'governo prepara pacote inclui crédito empresa demitir',
#  'palmeiras fecha zagueiro victor ramos anúncio dia',
#  '',
#  'morre gaitista blues james cotton parceiro muddy waters anos',
#  'itália aprova missão líbia conter migrantes',
#  'novela fábula transformação paulo halm',
#  'eua sugerem americano exposto zika adote abstinência sexual',
#  'estados unidos plantam soja milho oferta brasileira',
#  'dependentes anos passam precisar cpf',
#  'ataque hospital síria recebe msf mata deixa feridos',
#  'cbda aprova mudanças estatuto altera regras eleição presidencial',
#  'série justiça globo explora nuances lei vingança',
#  'má fase pressão corinthians enfrenta vitória brasileiro',
#  'debate machado safadeza perguntas indiscretas',
#  'maconha legalizada ar cool denver sucesso econômico',
#  'atentado mata festa dia bastilha sul frança',
#  'economistas ajudam deixar última hora',
#  'estilista espanhol david delfín morre vítima câncer anos',
#  'luz comida baratos brasil deflação anos',
#  'populismo europeu continua vivo apesar derrota marine le pen',
#  'herói barcelona gol clube havia ano',
#  'empresas respondem quase dívida união',
#  'lula aceitar convite dilma ministro',
#  'jogo título aberto austrália federer massacra francês',
#  'brasil lava jato palocci teria sido abatido',
#  'corpo salvador dalí será exumado teste paternidade',
#  'cruzeiro vence sesi conquista superliga masculina vôlei',
#  'promotoria investiga propina paga corregedoria proteger policiais',
#  'lula defeitos ajuste fiscal poderiam sido corrigidos',
#  'valdivia corre risco suspensão paulista',
#  'julgamento físico ufrj serviu justificar prisão advogado',
#  'reality shows vivem queda audiência repercussão tv',
#  'argentina cronograma ajudar importadores saldar dívida',
#  'israelenses detidos faixa gaza netanyahu',
#  'forças segurança reprimem protesto caracas',
#  'virada real madrid vence barcelona casa',
#  'redes sociais chargistas prestam homenagem mortos frança',
#  'percussionista naná vasconcelos internado uti recife',
#  'erramos vizinhos ficam chocados prisão mulher acusada morte marido',
#  'hungria campanha george soros incentivar imigração ilegal',
#  'atropelos fechar paulista ofuscam ação respaldada urbanistas',
#  'cela mandela candidatar fifa',
#  'homem morre atingido raio paulo chuva derruba árvores',
#  'piloto morre queda avião acrobacias durante show salvador',
#  'the affair traz olhar traídos temporada',
#  'estúdio star wars reconhece falha acidente harrison ford',
#  'técnico santos será julgado desobedecer suspensão brasileiro',
#  'metrô paulo perde passageiros anos',
#  'seleção minimiza erro arbitragem daniel alves pede mudança',
#  'paulo volta luis fabiano poupa estreia brasileiro',
#  'ano seca samarco elevou consumo água',
#  'inserção brasil economia global tema debate série diálogos',
#  'obama aumentar pressão rússia mortes ucrânia',
#  'produtora prepara documentários clubes paulistanos',
#  'governo francês promete ajuda vítimas enchentes',
#  'erramos camargo corrêa virar siemens',
#  'esquiadores saltam metros prova áustria',
#  'projeto ajuda usuárias drogas evitar gravidez planejada',
#  'metade paulistanos morar periferia datafolha',
#  'suspeito atacar ônibus borussia islâmico procuradoria',
#  'bolsas chinesas alta índice asiático cai',
#  'silvio santos datena será candidato prefeito sp',
#  'oba hoje dia zoar ceni',
#  'cunha embate político ética câmara',
#  'equador manda volta cuba pessoas tentavam chegar eua',
#  'dia brasil chance ouro finais copa ginástica',
#  'grávida anos caso confirmado zika sp',
#  'sobe mortes centros detenção estrangeiros japão',
#  'dólar cai semanas exterior volume fraco',
#  'brie larson carrega garra leveza longa jack',
#  'dólar avança exterior negativo ação bc bolsa cai',
#  'mandaram gente correr atiraram balas borracha',
#  'coloca venda ingressos ginástica canoagem remo',
#  '',
#  'jogo difícil seleção masculina basquete apega torcida vitória',
#  'dona compra óticas carol negócio milhões',
#  'crítica voz potente bethânia surpreende antigos fãs',
#  'meirelles defende juro bndes falar chefe banco',
#  'iphone considerado produto rentável história',
#  'david uip prepara livro dados crise incor santa casa',
#  'prefeitura investiga taxa cobrada trios elétricos parada gay sp',
#  'zé caixão refaz trajetória cineasta maldito brasil',
#  'haiti trabalhará grupos políticos',
#  'república tcheca eslováquia rejeitam receber refugiados',
#  'erramos cidade venezuelana eua prefeito veio país',
#  'según un informe las obras los juegos olímpicos río dejaron un saldo nueve muertos',
#  'irmãos grael buscam repetir feito família',
#  'andrade vieira morre anos paraná',
#  'eua preparados ações regime sírio',
#  'renascimento vinil salva fábrica tcheca falência',
#  'presidente tenta conseguir eleição turquia',
#  'prefeitura sp busca patrocínio mi carnaval rua',
#  'jogador brasileiro nba recusa convocação',
#  'semana nacional boi neon kubrick brian palma',
#  'raivas europa grécia brasil',
#  'uruguai renuncia escândalo uso cartões',
#  'peças usadas stallone arrematadas milhões leilão',
#  'turbulências comerciais visita temer china',
#  'vidigal complexo alemão amanhecem ações pm rio',
#  'museu curitiba exibe gravura joan miró apreendida lava jato',
#  'bc eua mantém juros deixa alta dezembro aberto',
#  'tabu alemanha publicará edição crítica luta',
#  'livros mostra analisam universo sexomaníaco hudinilson jr',
#  'podemos desperdiçar tecnologia haddad aplicativo uber',
#  'chatô registra bilheteria fraca durante semana estreia',
#  '',
#  'neta picasso planeja venda obras artista preocupando mercado',
#  'paulo revisará contratos orlando city empresa hong kong',
#  '',
#  'pantanal incomodou globo mandamentos',
#  'maria inês dolci adiamento fies inaceitável',
#  'mortes advogado oratória forte apaixonada',
#  'tommy hilfiger gigi hadid dividem coleção semana moda ny',
#  'helena ranaldi contracena anões clássico ibsen vídeo',
#  'toronto melhor coxinha brasil',
#  '',
#  'confira brasileiros presos suspeita ligação terrorismo',
#  'análise snl trouxe tv ousadia humor agressivo desrespeitoso',
#  'honduras admite culpado caso corrupção fifa',
#  '',
#  'corpo elétrico jovem gay foge estereótipos explora sensualidade',
#  'chuvas rio matam deixam centenas desabrigados',
#  'banidos blatter platini terão candidatos eleição fifa',
#  'visto brasileiro comum eua',
#  'reencenações realçam drama menino pieguice',
#  'nuno ramos será sabatinado folha terça mis',
#  'abertura china brasil cautela obama',
#  'álbum frank ocean boys cry lançado',
#  'cena eletrônica brasileira amadurece produção própria',
#  'américa sul ricos pobres ajudam afirmou bowie folha',
#  'retorno inflação alta milionários fogem poupança',
#  'alalaô blocos alta paulistanos decidem passar carnaval cidade',
#  'multitela guerra civil traz conflito principais heróis marvel',
#  'kareem publicar livro irmão sherlock holmes',
#  'itália retira imigrantes barcos interceptados mediterrâneo',
#  'prefeitura paulo inaugura salas públicas cinema',
#  'amor rasgado fãs explicam fenômeno cristiano araújo',
#  'chuva deixa sp atenção precipitação esperada',
#  'família fellini vende direitos refilmagem doce vida',
#  'papa francisco adverte ambição pessoal individualismo',
#  'aliados temer serra ficam aliviados revelação caixa odebrecht',
#  'hoje tv futebol americano copa mundo rúgbi',
#  '',
#  'dilma precisa convencer empresariado eua fundador consultoria',
#  'patrocinadores fifa influenciam reformas entidade',
#  'jogo gols corinthians vence assume liderança brasileiro',
#  'atitude dupla atletiba verdadeira emancipação clubes',
#  'diretor charlie hebdo lista procurados',
#  'curadorias pegam onda feira artrio criam mostras paralelas',
#  'yoná pessoa luminosa leia repercussão morte atriz',
#  'olhar inquieto thomas bernhard recebe montagem sp',
#  'levantamento mostra oscar marginaliza negros',
#  'mercado reduz projeção inflação ano vê leve piora pib',
#  'morador paulista será cadastrado carro domingos via',
#  'whatsapp vira alternativa empresas',
#  'crise medalhas cuba finais boxe ameaça brasil',
#  'festival documentários musicais traz filmes inglês tony palmer',
#  'pragmatismo derrota ilusão curto espaço grécia',
#  'ator maurice durozier théâtre du soleil encena espetáculo solo sp',
#  'pleased to prove that brazil can run an olympics said the president of the brazilian olympic committee',
#  'morrem vítima autor ataque fogo trem suíça',
#  'presídio manaus permitiu visitas risco fuga ministro',
#  'ministro fazenda barbosa meta conter gastos',
#  'atentado bomba deixa mortos diplomática cabul',
#  'ninguém deseja mudanças quintal presidente stefanini',
#  'cuca felipe melo joga palmeiras',
#  'ana paula arósio traduzir livro opção emprego der certo',
#  'veto rolezinhos shoppings sp fracassa justiça',
#  'ativista ferido cabeça ato mpl licença médica metrô',
#  'gás total cirurgia pupo prepara mundial surfe',
#  'fundo setorial audiovisual utilizou recursos condecine',
#  'tradicional feira arte holandesa tefaf anuncia edições york',
#  'moreira franco permanecer governo rodrigo maia',
#  'presos facções am presídios federais ministro',
#  'venda marmitas diminui crise construção indústria',
#  'jar jar binks inspirado pateta revela george lucas',
#  'neymar será julgado expulsão suspenso jogos',
#  'prisão josé dirceu completa anos',
#  'china mira trabalhador migrante reduzir estoque imóveis cidades',
#  'superior américa sul brasil enfrentar europa',
#  'produtores negociaram safra recorde café',
#  'conflito ucrânia teste eua moscou',
#  'avião militar cai mata militares colômbia',
#  'sobreviventes voo chapecoense ficarão dias internados colômbia',
#  'solução enlouquecedor silêncio ignorados',
#  'tv mostra carro doria parado frente placa proibido estacionar',
#  'alessandra negrini josé eduardo belmonte convidados tv folha',
#  'entender reoneração folha pagamentos',
#  'desenquadrados carnaval fãs rock criam opções feriado',
#  'concessões esperar conclusão impeachment ministro',
#  'dívida juro alto paga gastar',
#  'investimento imobiliário vendas china aceleram setembro',
#  'água uso industrial sobra sp vira opção ambiental empresas',
#  'ingresso bienal livro sp caro',
#  'bolsas asiáticas dia instável china radar fecham alta',
#  'cruzeiro tenta equipe títulos seguidos superliga',
#  'empresas trabalham calibrar melhor indicadores prédios verdes',
#  'amei grávida professora mãe solidária britânica',
#  'nuno ramos impeachment narrado bossa jn',
#  'fundador porta fundos terá interferência dona mtv',
#  'paulo confia fase líderes clássico paulista',
#  'maternar mãe quadrigêmeos morre dia parto',
#  'anos rafael coutinho lança novela gráfica',
#  'dia papai celebrado paulo anos',
#  'livros josé veiga ganham reedição',
#  'comunidade judaica avalia significado ascensão discreto judeu sanders',
#  'cortes falhas emperram obras alckmin interligar cidades sp',
#  'agência inaugura tour lava jato curitiba inclui presídio',
#  'sp doria moda brasil',
#  'risco perder braço jovem atropelado rua augusta estável',
#  'justiça determina prisão suspeitos morte turista italiano rio',
#  'incêndio atinge loja região central sp deixa pessoa intoxicada',
#  'corinthians estilo jogar marca época vencedora',
#  'gastos governo infraestrutura atingem percentual histórico',
#  '',
#  'mostra exibe clássicos raridades cinema engajado irmãos dardenne',
#  'alemanha gols zimbábue marca olimpíadas',
#  'sumiço técnico encontrado passa polícia',
#  'terno dubla própria canção clipe culpa single álbum',
#  'ação militar coreia norte improvável',
#  'prestes completar anos leonard cohen prepara álbum',
#  '',
#  'outro canal gnt contrata marcelo tas dan stulbach',
#  'justiça federal decide arquivar denúncia família neymar',
#  'obama discorda discriminação religião fala valores ameaçados',
#  'brasil terá metade população ativa apta aposentar ocde',
#  'ascensão equipes santa catarina vivem ameaça queda',
#  '',
#  '',
#  'candidatos opositores cuba biografias alteradas',
#  'filme sofia coppola criticado excluir personagem negra história',
#  'jogador uruguaio morre dias acidente ônibus venezuela',
#  'mortes fã presépios modista criou filhos',
#  'youtubers farão campanha ministério saúde divulgar vacinação',
#  'discos geração lapa carioca tira samba pedestal',
#  'pan tv brasil x venezuela basquete masculino atletismo',
#  'ipi reduzido impulsionou financiamento carros dezembro',
#  'acidente ônibus nepal deixa mortos feridos',
#  '',
#  'ingressos amistoso seleção estádio palmeiras venda',
#  'erramos prefeito haddad volta aulas usp anos docência',
#  'mural interdições religiosos realizam ato intolerância itaquera',
#  'fabiana beltrame conquista prata remo',
#  'china barrar choque tratar viciado internet',
#  'analistas motivação assad ataque químico enigma',
#  'pão diabo encareceu',
#  '',
#  'tilda swinton emudece viver rock star filme festival veneza',
#  'vigilante amanhã nutre legado deixado hqs anos',
#  'paulo betti leva palcos ambiente inóspito poético infância',
#  'bon jovi horas show hits ignora pedido fãs',
#  'sabesp metrô terão departamento anticorrupção ano',
#  'manifestantes invadem secretaria segurança sp ato chacina',
#  'anvisa dará aval temporário pesquisas aedes transgênico',
#  'vereadores paulo aprovam aumento cargos gabinetes',
#  'calendário apertado seleções temerem gramados copa américa',
#  'tremor magnitude atinge norte colômbia',
#  'empresas dançam adaptar dólar redor',
#  'mãe merece feto vida juiz aborto caso microcefalia',
#  'disputa política prefeito cidade espanhola trabalhar graça',
#  'artista google street view refletir internet exposição',
#  'centenário jazz folha lança coleção nomes gênero',
#  'goosebumps susto fácil procura riso inteligente',
#  'dólar recua discurso realista levy senado',
#  'reunião produtiva deu banho sangue charlie hebdo',
#  'palmeiras estende contrato atacante luan',
#  'conflito presídio ataques ruas preocupam turistas natal',
#  'forças armadas vistoria presídios nordeste',
#  'brasil perde time mundial handebol',
#  'anos centro pompidou passou fábrica horrível ícone parisiense',
#  'acordo prefeitura união prevê parque campo marte',
#  'marcelo odebrecht itaquerão pepino mendigo',
#  'lesionado volante gabriel perguntou médicos palmeiras jogar',
#  'crise política presidente guatemala renunciará',
#  'acho estaria desempregado fossem mulheres nick hornby',
#  'erramos iggy pop quebra óculos gigante posa fãs spfw',
#  'revisão pib ibge afastar recessão',
#  'crise gestão alckmin tratar água rio pinheiros',
#  ...]

# %%
df_titulos_tratados = pd.DataFrame({"titulo": textos_tratados})
df_titulos_tratados.head()
# Out:
#                                               titulo
# 0  polêmica marine le pen abomina negacionistas h...
# 1  macron le pen turno frança revés siglas tradic...
# 2  apesar larga vitória legislativas macron terá ...
# 3  governo antecipa balanço alckmin anuncia queda...
# 4       queda maio atividade econômica sobe junho bc

# %%
print(len(df_titulos_tratados))
df_titulos_tratados = df_titulos_tratados.dropna().drop_duplicates()
print(len(df_titulos_tratados))
# Out:
# 90000
# 84467

# %%
lista_lista_tokens = [titulo.split(" ") for titulo in df_titulos_tratados.titulo]

# %%
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

class LossPrinterCallback(CallbackAny2Vec):
  def __init__(self):
    self.epoch = 0
    self.loss_previous_step = 0
  
  def on_epoch_end(self, model):
    loss = model.get_latest_training_loss()
    if self.epoch == 0:
      print(f"Loss após a época {self.epoch}: {loss}")
    else:
      print(f"Loss após a época {self.epoch}: {loss}")
    self.epoch += 1
    self.loss_previous_step = loss

# sg == 0 -> CBOW
# sg == 1 -> Skip-Gram
w2v_modelo = Word2Vec(sg=0, # CBOW
                      window=2,
                      vector_size=300,
                      min_count=5,
                      alpha=0.03,
                      min_alpha=0.007,
                      compute_loss=True)
w2v_modelo.build_vocab(lista_lista_tokens, progress_per=5000)

# %%
w2v_modelo.corpus_count
# Out:
# 84467

# %%
w2v_modelo.train(lista_lista_tokens, 
                 total_examples=w2v_modelo.corpus_count,
                 epochs=30,
                 callbacks=[LossPrinterCallback()])
# Out:
# Loss após a época 0: 0.0
# Loss após a época 1: 0.0
# Loss após a época 2: 0.0
# Loss após a época 3: 0.0
# Loss após a época 4: 0.0
# Loss após a época 5: 0.0
# Loss após a época 6: 0.0
# Loss após a época 7: 0.0
# Loss após a época 8: 0.0
# Loss após a época 9: 0.0
# Loss após a época 10: 0.0
# Loss após a época 11: 0.0
# Loss após a época 12: 0.0
# Loss após a época 13: 0.0
# Loss após a época 14: 0.0
# Loss após a época 15: 0.0
# Loss após a época 16: 0.0
# Loss após a época 17: 0.0
# Loss após a época 18: 0.0
# Loss após a época 19: 0.0
# Loss após a época 20: 0.0
# Loss após a época 21: 0.0
# Loss após a época 22: 0.0
# Loss após a época 23: 0.0
# Loss após a época 24: 0.0
# Loss após a época 25: 0.0
# Loss após a época 26: 0.0
# Loss após a época 27: 0.0
# Loss após a época 28: 0.0
# Loss após a época 29: 0.0
# (14584748, 16207290)

# %%
w2v_modelo.wv.most_similar("google")
# Out:
# [('apple', 0.5803342461585999),
#  ('facebook', 0.523070752620697),
#  ('amazon', 0.4783187210559845),
#  ('tesla', 0.467632532119751),
#  ('airbnb', 0.46067577600479126),
#  ('uber', 0.4569011926651001),
#  ('software', 0.4511861503124237),
#  ('yahoo', 0.44767510890960693),
#  ('news', 0.44306471943855286),
#  ('sony', 0.43277955055236816)]

# %%
w2v_modelo.wv.most_similar("microsoft")
# Out:
# [('unilever', 0.5689483880996704),
#  ('amazon', 0.5252668857574463),
#  ('spotify', 0.5121902227401733),
#  ('braskem', 0.4998159110546112),
#  ('canais', 0.4972003996372223),
#  ('tesla', 0.4913753569126129),
#  ('viajante', 0.4855427145957947),
#  ('lego', 0.48465925455093384),
#  ('sony', 0.4816015362739563),
#  ('edições', 0.45361068844795227)]

# %%
w2v_modelo.wv.most_similar("barcelona")
# Out:
# [('bayern', 0.5556474328041077),
#  ('barça', 0.5429335236549377),
#  ('chelsea', 0.5253135561943054),
#  ('madrid', 0.5170454382896423),
#  ('united', 0.5121796727180481),
#  ('psg', 0.5115708708763123),
#  ('munique', 0.5104071497917175),
#  ('mourinho', 0.503070056438446),
#  ('juventus', 0.4980230927467346),
#  ('lazio', 0.4977955222129822)]

# %%
w2v_modelo.wv.most_similar("boxe")
# Out:
# [('canoagem', 0.6048121452331543),
#  ('rúgbi', 0.590907096862793),
#  ('taekwondo', 0.5796389579772949),
#  ('handebol', 0.5791224241256714),
#  ('duplas', 0.5637231469154358),
#  ('judô', 0.5619280934333801),
#  ('esgrima', 0.549457848072052),
#  ('fiji', 0.5486482381820679),
#  ('triatlo', 0.5308200120925903),
#  ('poliana', 0.5252306461334229)]

# %%
w2v_modelo_sg = Word2Vec(sg=1, # Skip-Gram
                         window=2,
                         vector_size=300,
                         min_count=5,
                         alpha=0.03,
                         min_alpha=0.007,
                         compute_loss=True)
w2v_modelo_sg.build_vocab(lista_lista_tokens, progress_per=5000)
w2v_modelo_sg.train(lista_lista_tokens, 
                    total_examples=w2v_modelo.corpus_count,
                    epochs=30,
                    callbacks=[LossPrinterCallback()])
# Out:
# Loss após a época 0: 0.0
# Loss após a época 1: 0.0
# Loss após a época 2: 0.0
# Loss após a época 3: 0.0
# Loss após a época 4: 0.0
# Loss após a época 5: 0.0
# Loss após a época 6: 0.0
# Loss após a época 7: 0.0
# Loss após a época 8: 0.0
# Loss após a época 9: 0.0
# Loss após a época 10: 0.0
# Loss após a época 11: 0.0
# Loss após a época 12: 0.0
# Loss após a época 13: 0.0
# Loss após a época 14: 0.0
# Loss após a época 15: 0.0
# Loss após a época 16: 0.0
# Loss após a época 17: 0.0
# Loss após a época 18: 0.0
# Loss após a época 19: 0.0
# Loss após a época 20: 0.0
# Loss após a época 21: 0.0
# Loss após a época 22: 0.0
# Loss após a época 23: 0.0
# Loss após a época 24: 0.0
# Loss após a época 25: 0.0
# Loss após a época 26: 0.0
# Loss após a época 27: 0.0
# Loss após a época 28: 0.0
# Loss após a época 29: 0.0
# (14584320, 16207290)

# %%
w2v_modelo_sg.wv.most_similar("google")
# Out:
# [('waze', 0.43154364824295044),
#  ('reguladores', 0.4217996597290039),
#  ('apple', 0.421257346868515),
#  ('facebook', 0.42067137360572815),
#  ('exxon', 0.41168245673179626),
#  ('toshiba', 0.39374449849128723),
#  ('snapchat', 0.3850712478160858),
#  ('monsanto', 0.3802107572555542),
#  ('verizon', 0.3796663284301758),
#  ('walmart', 0.3759676516056061)]

# %%
w2v_modelo_sg.wv.most_similar("gm")
# Out:
# [('metalúrgicos', 0.618873119354248),
#  ('volks', 0.5789728760719299),
#  ('chrysler', 0.5740767121315002),
#  ('csn', 0.5697442293167114),
#  ('fiat', 0.5673325657844543),
#  ('honda', 0.5613058805465698),
#  ('toyota', 0.5596768260002136),
#  ('cubatão', 0.5447432398796082),
#  ('excedente', 0.541062593460083),
#  ('bp', 0.5403484106063843)]

# %%
w2v_modelo.wv.most_similar("gm")
# Out:
# [('embraer', 0.6474800109863281),
#  ('volks', 0.6422678828239441),
#  ('braskem', 0.6396070718765259),
#  ('chrysler', 0.6378303170204163),
#  ('tesla', 0.6172362565994263),
#  ('volkswagen', 0.601786196231842),
#  ('honda', 0.6006880402565002),
#  ('toyota', 0.5977849960327148),
#  ('sony', 0.5918664336204529),
#  ('renault', 0.5793024301528931)]

# %%
w2v_modelo.wv.save_word2vec_format("/content/drive/MyDrive/ml-dataset/word2vec2/modelo_cbow.txt",
                                   binary=False)

# %%
w2v_modelo_sg.wv.save_word2vec_format("/content/drive/MyDrive/ml-dataset/word2vec2/modelo_skipgram.txt",
                                      binary=False)

# %%
import spacy
import numpy as np
from gensim.models import KeyedVectors

nlp = spacy.load("pt_core_news_sm", disable=["parser", "ner", "tagger", "textcat"])
w2v_modelo_cbow = KeyedVectors.load_word2vec_format("/content/drive/MyDrive/ml-dataset/word2vec2/modelo_cbow.txt")
w2v_modelo_skipgram = KeyedVectors.load_word2vec_format("/content/drive/MyDrive/ml-dataset/word2vec2/modelo_skipgram.txt")

# %%
def tokenizador(texto):
  doc = nlp(texto)
  tokens = []

  for token in doc:
    eh_valido = not token.is_stop and token.is_alpha
    if eh_valido:
      tokens.append(token.text.lower())

  return tokens

def combinacao_vetores_por_soma(palavras, modelo):
  vetor_resultante = np.zeros(300)
  for token in palavras:
    try:
      vetor_resultante += modelo.get_vector(token)
    except KeyError:
      pass

  return vetor_resultante

def get_matriz(textos, modelo):
  x = len(textos)
  y = 300
  matriz = np.zeros((x, y))
  for i in range(x):
    palavras = tokenizador(textos.iloc[i])
    matriz[i] = combinacao_vetores_por_soma(palavras, modelo)
  return matriz

# %%
tokens = tokenizador("Rio de Janeiro 12314312 ******** @#$ é uma cidade linda!")
print(tokens)
# Out:
# ['rio', 'janeiro', 'cidade', 'linda']

# %%
vetor_texto = combinacao_vetores_por_soma(tokens, w2v_modelo_cbow)
print(vetor_texto.shape)
print(vetor_texto)
# Out:
# (300,)
# [ 5.13054579e-02  7.19350576e-03  6.72219116e-02 -1.58674987e+00
#   5.74549020e-01  1.32542326e+00 -1.57522754e+00  3.74815673e-01
#   6.92363519e-01 -1.75550605e+00 -2.78070397e-01  1.15573588e+00
#  -7.95041338e-01 -1.49040878e-01  2.70537119e-02 -2.50820536e+00
#  -9.73513037e-01 -6.59038484e-01 -1.51715502e-01  2.72062382e-01
#  -3.10715377e-01 -1.05958773e+00 -8.03802423e-02  8.93911792e-01
#  -1.21215641e-01 -1.18663660e+00  8.22006881e-01 -2.33630363e-01
#   1.76654570e-01  8.03269535e-01 -4.99088332e-01 -2.45244215e+00
#  -1.95457451e-01  1.75627010e+00  1.52922887e+00 -5.59322208e-01
#  -1.59591080e+00 -1.98021813e+00  1.16661733e+00 -4.61944148e-01
#  -5.25807045e-01  7.17933692e-01  9.70833503e-01 -6.81076908e-01
#  -2.75706476e+00 -5.10843001e-01  1.85745910e+00 -1.00655728e+00
#   1.99195087e+00 -5.01448214e-02 -4.71750705e-01 -2.97135030e+00
#   7.74533149e-01 -2.33750699e+00 -3.14629041e-01  1.42121722e+00
#   1.46278271e+00 -1.13704277e+00  7.81431183e-01  6.44952543e-01
#  -1.41763126e+00 -3.22928411e+00  5.70518967e-01 -1.12001082e+00
#   2.51104616e+00 -3.94152570e-01 -2.30175324e-01  3.88492972e-01
#  -2.11088648e-01 -7.88031518e-03  6.80464864e-01  2.04205072e+00
#   3.33466772e-02 -1.19121745e+00  1.10601778e+00  6.71649642e-01
#  -4.25800681e-03 -9.37362231e-01 -2.39010011e+00  1.33857915e+00
#  -1.07544926e+00  3.30405314e+00 -1.03688050e+00  1.36241504e+00
#  -2.16399536e-01 -1.37342922e+00  1.04697742e-01  6.27944112e-01
#  -1.04566801e+00 -9.02702540e-01  6.14070643e-01  2.25638233e-01
#  -1.06327485e+00 -3.44312131e-01 -6.13502115e-02  8.93134169e-01
#   1.61059474e+00  7.97416657e-01 -5.23380746e-01  8.75018939e-01
#   2.97679871e-01  4.67485189e-03 -4.08804610e-01  2.14168876e-02
#  -4.68856156e-01  1.68723746e+00 -1.50571803e+00  2.60502470e+00
#  -2.13782330e+00 -7.45793596e-01  1.03559664e-01  3.04266501e-01
#   3.60888588e-01 -8.79435770e-01  1.06860272e+00  1.05150820e+00
#  -1.12359565e-01 -1.33007218e+00 -2.05755975e+00 -1.67788173e+00
#   1.35743141e+00  1.42113873e+00  3.39974552e-01  9.88919325e-01
#   3.78575921e-01  4.40363890e+00 -1.53148060e+00 -3.41334377e+00
#   3.28836672e-01  4.57465689e+00  2.45159686e+00 -1.52957479e+00
#   1.67283050e+00 -3.21619412e+00  1.01461223e+00 -2.38442110e+00
#  -1.01064400e+00  1.68743340e+00  1.18139816e+00 -7.39881687e-01
#  -5.55934427e-01 -1.49048229e+00 -4.25573364e-02  1.86435987e+00
#   1.88171700e+00 -1.93006444e+00 -2.15961760e+00 -1.42873045e+00
#   6.54287241e-01  1.26382732e+00  4.78838608e-02 -3.39993757e+00
#  -1.25813527e+00 -9.84254636e-01  1.39061231e+00  2.82785654e-01
#   1.64295305e+00 -1.63002763e+00 -7.34581500e-01  4.65215155e+00
#   1.31404414e+00  7.40742773e-01  1.67515871e+00 -2.87717044e-01
#   1.90695240e+00  9.18881141e-01  3.29821751e-01  1.56709037e+00
#   6.75399385e-01  7.21141875e-01  5.86609356e-01  1.86140150e-01
#  -3.76293145e-01 -3.84309391e-01  1.07552771e+00  9.70093355e-01
#   2.05479401e+00  6.99394420e-01  6.95737395e-01 -1.08354210e-01
#  -2.85375126e-01 -5.82632884e-01 -1.07636988e-01  7.73800211e-02
#  -5.19989595e-01  8.80667493e-01 -5.54136626e-01  6.26494932e-01
#   1.85610688e+00 -7.87367936e-01  8.58341247e-01  3.28937796e+00
#  -1.43755828e+00  5.72193525e-01 -2.84809250e-01 -1.46861675e+00
#   1.72606105e+00  3.85808293e-01  9.77458125e-01 -5.69264682e-01
#  -1.30753182e+00  1.22720037e+00 -2.00306401e-01  1.40632126e+00
#   1.55037485e-01 -2.39069447e-01  2.07801758e+00  1.61362991e+00
#   2.48797999e+00 -1.31919041e+00 -6.74113482e-01 -1.06365238e+00
#  -1.90009549e+00 -1.09120212e-01 -1.32102021e+00 -1.30191627e+00
#   1.37183739e+00  5.64432697e-01 -1.47130388e+00 -3.18947318e+00
#  -6.07499376e-01  1.03421519e+00  1.35942724e+00 -1.05558981e+00
#  -1.86990319e+00  1.73721883e+00  7.72640504e-01 -2.03073951e+00
#  -1.93675457e+00 -2.10316817e+00 -1.75353885e+00  3.39725264e-02
#   6.42539322e-01 -9.36286338e-01 -1.50330535e+00 -1.31903616e+00
#  -7.41079442e-01  1.90586731e-01  1.70578571e+00 -4.82268110e-02
#   1.59977796e+00 -9.56549637e-01  2.30548595e+00 -2.40513853e+00
#   2.33289315e+00 -9.80712526e-01 -8.59923407e-01 -8.55551660e-03
#  -1.04310665e+00 -1.50303014e+00  1.58368685e+00  3.09356555e+00
#   1.89061895e+00 -9.81840461e-01  2.79753430e-01 -2.17187505e+00
#   1.72878369e+00 -2.83894971e-01 -2.68922877e+00 -1.05123705e+00
#   6.93526808e-01 -1.08076499e+00  2.81987488e-02  7.80958772e-01
#  -9.27387118e-01 -1.85463554e+00 -7.24302754e-02  7.98097193e-01
#  -2.49877046e+00 -3.84677279e+00 -3.12218942e+00  2.46560311e+00
#  -5.55218697e-01  1.00191044e-01  5.26236814e-01 -1.03076912e+00
#   1.85590552e+00  6.35237952e-01 -1.41749986e+00 -1.01688943e+00
#  -6.21814802e-02 -5.38219442e-01 -1.42662917e+00  9.26909953e-01
#   3.08676790e+00  4.48285043e-01 -1.85924771e+00 -2.03644523e+00
#  -9.69418414e-01 -6.16031449e-01 -1.91062286e-01  1.90454336e+00
#   1.82391810e+00  3.38851392e-01  5.83914716e-01 -3.72761499e-01
#  -1.30267754e-01  2.17262036e+00  7.54577003e-01  8.34828092e-01]

# %%
matriz_treino_cbow = get_matriz(df_treino.title, w2v_modelo_cbow)
matriz_teste_cbow = get_matriz(df_teste.title, w2v_modelo_cbow)

matriz_treino_skipgram = get_matriz(df_treino.title, w2v_modelo_skipgram)
matriz_teste_skipgram = get_matriz(df_teste.title, w2v_modelo_skipgram)

print((matriz_treino_cbow.shape, matriz_teste_cbow.shape))
print((matriz_treino_skipgram.shape, matriz_teste_skipgram.shape))
# Out:
# ((90000, 300), (20513, 300))
# ((90000, 300), (20513, 300))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

def classificador(modelo, x_treino, y_treino, x_teste, y_teste):
  modelo_lr = LogisticRegression(max_iter=300)
  modelo_lr.fit(x_treino, y_treino)
  categorias = modelo_lr.predict(x_teste)
  resultados = classification_report(y_teste, categorias)
  print(resultados)
  return modelo_lr

cbow_lr = classificador(w2v_modelo_cbow, 
                        matriz_treino_cbow, 
                        df_treino.category,
                        matriz_teste_cbow,
                        df_teste.category)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#      colunas       0.80      0.71      0.75      6103
#    cotidiano       0.64      0.80      0.71      1698
#      esporte       0.92      0.86      0.89      4663
#    ilustrada       0.13      0.87      0.23       131
#      mercado       0.84      0.78      0.81      5867
#        mundo       0.74      0.84      0.79      2051
#
#     accuracy                           0.79     20513
#    macro avg       0.68      0.81      0.70     20513
# weighted avg       0.82      0.79      0.80     20513

# %%
skipgram_lr = classificador(w2v_modelo_skipgram, 
                           matriz_treino_skipgram, 
                           df_treino.category,
                           matriz_teste_skipgram,
                           df_teste.category)
# Out:
#               precision    recall  f1-score   support
#
#      colunas       0.81      0.71      0.76      6103
#    cotidiano       0.64      0.80      0.71      1698
#      esporte       0.93      0.87      0.90      4663
#    ilustrada       0.13      0.86      0.23       131
#      mercado       0.83      0.79      0.81      5867
#        mundo       0.74      0.84      0.79      2051
#
#     accuracy                           0.79     20513
#    macro avg       0.68      0.81      0.70     20513
# weighted avg       0.82      0.79      0.80     20513

# %%
import pickle

with open("/content/drive/MyDrive/ml-dataset/word2vec2/cbow_lr.pkl", "wb") as f:
  pickle.dump(cbow_lr, f)

with open("/content/drive/MyDrive/ml-dataset/word2vec2/skipgram_lr.pkl", "wb") as f:
  pickle.dump(skipgram_lr, f)
